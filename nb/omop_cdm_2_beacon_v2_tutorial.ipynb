# %% [markdown]
# ## OMOP CDM to Beacon v2 Models
# Google Colab to perform the conversion from a PosgreSQL export to the _individuals_ entity of the [Beacon v2 Models](https://docs.genomebeacons.org/schemas-md/individuals_defaultSchema)

# %% [markdown]
# # Installation of the software `Convert-Pheno`

# %% [markdown]
# *Note:* We'll perform an installation directly from the [GitHub](https://github.com/mrueda/convert-pheno) source.
#
# First we will download the repository by using `git clone`

# %%
# !git clone https://github.com/CNAG-Biomedical-Informatics/convert-pheno.git
# Out:
# Cloning into 'convert-pheno'...
# remote: Enumerating objects: 8630, done.
# remote: Counting objects: 100% (677/677), done.
# remote: Compressing objects: 100% (347/347), done.
# remote: Total 8630 (delta 343), reused 508 (delta 242), pack-reused 7953 (from 2)
# Receiving objects: 100% (8630/8630), 163.05 MiB | 12.91 MiB/s, done.
# Resolving deltas: 100% (4905/4905), done.
# Updating files: 100% (243/243), done.

# %% [markdown]
# Now we enter into `convert-pheno` directory:

# %%
# %cd convert-pheno/
# Out:
# /content/convert-pheno

# %% [markdown]
# And we perform the installation of the needed dependencies.
# Note that this task will take **a few minutes** to complete...

# %%
# !make -f makefile.install install
# Out:
# sudo apt-get install cpanminus libbz2-dev zlib1g-dev libperl-dev
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libbz2-dev is already the newest version (1.0.8-5build1).
# libbz2-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   libalgorithm-c3-perl libany-uri-escape-perl libb-hooks-endofscope-perl
#   libb-hooks-op-check-perl libclass-c3-perl libclass-c3-xs-perl
#   libclass-method-modifiers-perl libclass-xsaccessor-perl libclone-perl
#   libcpan-changes-perl libcpan-distnameinfo-perl libcpan-meta-check-perl
#   libdata-optlist-perl libdata-perl-perl libdata-section-perl
#   libdevel-callchecker-perl libdynaloader-functions-perl libencode-locale-perl
#   libexporter-tiny-perl libfile-pushd-perl libfile-slurp-perl
#   libgetopt-long-descriptive-perl libhtml-parser-perl libhtml-tagset-perl
#   libhttp-date-perl libhttp-message-perl libidn12 libimport-into-perl
#   libio-html-perl libio-stringy-perl liblist-moreutils-perl
#   liblist-moreutils-xs-perl liblocal-lib-perl liblwp-mediatypes-perl
#   libmodule-build-perl libmodule-cpanfile-perl libmodule-implementation-perl
#   libmodule-runtime-perl libmodule-signature-perl libmoo-perl
#   libmoox-handlesvia-perl libmro-compat-perl libnamespace-autoclean-perl
#   libnamespace-clean-perl libnet-libidn-perl libpackage-stash-perl
#   libpackage-stash-xs-perl libparams-classify-perl libparams-util-perl
#   libparams-validate-perl libparse-pmfile-perl libpath-tiny-perl
#   libpod-markdown-perl libpod-readme-perl libreadonly-perl libref-util-perl
#   libref-util-xs-perl librole-tiny-perl libsoftware-license-perl
#   libstrictures-perl libstring-shellquote-perl libsub-exporter-perl
#   libsub-exporter-progressive-perl libsub-identify-perl libsub-install-perl
#   libsub-name-perl libsub-quote-perl libtext-template-perl libtry-tiny-perl
#   libtype-tiny-perl libtype-tiny-xs-perl libunicode-utf8-perl
#   liburi-escape-xs-perl liburi-perl libvariable-magic-perl
# Suggested packages:
#   libdata-dump-perl libscalar-number-perl libbareword-filehandles-perl
#   libindirect-perl libmultidimensional-perl libdevel-lexalias-perl
#   libdevel-stacktrace-perl libbusiness-isbn-perl libwww-perl
# The following NEW packages will be installed:
#   cpanminus libalgorithm-c3-perl libany-uri-escape-perl
#   libb-hooks-endofscope-perl libb-hooks-op-check-perl libclass-c3-perl
#   libclass-c3-xs-perl libclass-method-modifiers-perl libclass-xsaccessor-perl
#   libclone-perl libcpan-changes-perl libcpan-distnameinfo-perl
#   libcpan-meta-check-perl libdata-optlist-perl libdata-perl-perl
#   libdata-section-perl libdevel-callchecker-perl libdynaloader-functions-perl
#   libencode-locale-perl libexporter-tiny-perl libfile-pushd-perl
#   libfile-slurp-perl libgetopt-long-descriptive-perl libhtml-parser-perl
#   libhtml-tagset-perl libhttp-date-perl libhttp-message-perl libidn12
#   libimport-into-perl libio-html-perl libio-stringy-perl
#   liblist-moreutils-perl liblist-moreutils-xs-perl liblocal-lib-perl
#   liblwp-mediatypes-perl libmodule-build-perl libmodule-cpanfile-perl
#   libmodule-implementation-perl libmodule-runtime-perl
#   libmodule-signature-perl libmoo-perl libmoox-handlesvia-perl
#   libmro-compat-perl libnamespace-autoclean-perl libnamespace-clean-perl
#   libnet-libidn-perl libpackage-stash-perl libpackage-stash-xs-perl
#   libparams-classify-perl libparams-util-perl libparams-validate-perl
#   libparse-pmfile-perl libpath-tiny-perl libperl-dev libpod-markdown-perl
#   libpod-readme-perl libreadonly-perl libref-util-perl libref-util-xs-perl
#   librole-tiny-perl libsoftware-license-perl libstrictures-perl
#   libstring-shellquote-perl libsub-exporter-perl
#   libsub-exporter-progressive-perl libsub-identify-perl libsub-install-perl
#   libsub-name-perl libsub-quote-perl libtext-template-perl libtry-tiny-perl
#   libtype-tiny-perl libtype-tiny-xs-perl libunicode-utf8-perl
#   liburi-escape-xs-perl liburi-perl libvariable-magic-perl
# 0 upgraded, 77 newly installed, 0 to remove and 2 not upgraded.
# Need to get 3,588 kB of archives.
# After this operation, 12.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcpan-distnameinfo-perl all 0.12-2.1 [8,276 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcpan-meta-check-perl all 0.014-1 [7,594 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfile-pushd-perl all 1.016-1 [12.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodule-build-perl all 0.423100-1 [200 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblocal-lib-perl all 2.000028-1 [47.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodule-cpanfile-perl all 1.1004-1 [24.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libparse-pmfile-perl all 0.43-1 [14.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libstring-shellquote-perl all 1.04-1 [12.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 cpanminus all 1.7045-1 [50.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libalgorithm-c3-perl all 0.11-1 [11.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 liburi-perl all 5.10-1 [78.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liburi-escape-xs-perl amd64 0.14-1build6 [14.7 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libany-uri-escape-perl all 0.01-3 [4,638 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libb-hooks-op-check-perl amd64 0.22-1build5 [10.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdynaloader-functions-perl all 0.003-1.1 [12.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdevel-callchecker-perl amd64 0.008-1ubuntu4 [14.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libparams-classify-perl amd64 0.015-1build5 [22.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmodule-runtime-perl all 0.016-1 [16.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtry-tiny-perl all 0.31-1 [21.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmodule-implementation-perl all 0.09-1.1 [11.6 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-exporter-progressive-perl all 0.001013-1 [6,784 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvariable-magic-perl amd64 0.62-1build5 [35.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libb-hooks-endofscope-perl all 0.25-1 [17.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclass-c3-perl all 0.35-1 [19.0 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclass-c3-xs-perl amd64 0.15-1build2 [16.7 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclass-method-modifiers-perl all 2.13-1 [16.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclass-xsaccessor-perl amd64 1.19-3build9 [34.1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclone-perl amd64 0.45-1build3 [11.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcpan-changes-perl all 0.400002-1.1 [27.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libparams-util-perl amd64 1.102-1build3 [22.7 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-install-perl all 0.928-1.1 [9,972 B]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdata-optlist-perl all 0.112-1 [11.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexporter-tiny-perl all 1.002002-1 [36.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblist-moreutils-xs-perl amd64 0.430-2build2 [41.9 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblist-moreutils-perl all 0.430-2 [38.2 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 librole-tiny-perl all 2.002004-1 [16.3 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libstrictures-perl all 2.000006-1 [16.3 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdata-perl-perl all 0.002011-1 [40.3 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmro-compat-perl all 0.15-1 [11.7 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-exporter-perl all 0.988-1 [50.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdata-section-perl all 0.200007-1 [11.8 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libencode-locale-perl all 1.05-1.1 [11.8 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfile-slurp-perl all 9999.32-1 [21.5 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-stringy-perl all 2.111-3 [55.8 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libparams-validate-perl amd64 1.30-1build3 [54.7 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgetopt-long-descriptive-perl all 0.109-2 [25.6 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-parser-perl amd64 3.76-1build2 [88.4 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-date-perl all 6.05-1 [9,920 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-html-perl all 1.004-2 [15.4 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-message-perl all 6.36-1 [76.8 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimport-into-perl all 1.002005-1 [11.0 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodule-signature-perl all 0.88-1 [21.8 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-quote-perl all 2.006006-1 [19.5 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmoo-perl all 2.005004-3 [48.0 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmoox-handlesvia-perl all 0.001009-1 [18.5 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpackage-stash-perl all 0.39-1 [19.1 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-identify-perl amd64 0.14-1build5 [10.4 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-name-perl amd64 0.26-1build3 [11.4 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnamespace-clean-perl all 0.27-1 [13.6 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnamespace-autoclean-perl all 0.29-1 [12.5 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-libidn-perl amd64 0.12.ds-3build6 [18.4 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpackage-stash-xs-perl amd64 0.29-1build5 [19.4 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpath-tiny-perl all 0.122-1 [45.9 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libperl-dev amd64 5.34.0-3ubuntu1.5 [1,140 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpod-markdown-perl all 3.300000-1 [29.2 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtype-tiny-perl all 1.012004-1 [321 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpod-readme-perl all 1.2.3-1 [33.3 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libreadonly-perl all 2.050-3 [19.9 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libref-util-perl all 0.204-1 [15.0 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libref-util-xs-perl amd64 0.117-1build5 [12.7 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtext-template-perl all 1.60-1 [49.4 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsoftware-license-perl all 0.104001-1 [115 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtype-tiny-xs-perl amd64 0.022-1build2 [25.5 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/main amd64 libunicode-utf8-perl amd64 0.62-1build4 [18.9 kB]
# Fetched 3,588 kB in 2s (2,124 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 77.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libcpan-distnameinfo-perl.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../00-libcpan-distnameinfo-perl_0.12-2.1_all.deb ...
# Unpacking libcpan-distnameinfo-perl (0.12-2.1) ...
# Selecting previously unselected package libcpan-meta-check-perl.
# Preparing to unpack .../01-libcpan-meta-check-perl_0.014-1_all.deb ...
# Unpacking libcpan-meta-check-perl (0.014-1) ...
# Selecting previously unselected package libfile-pushd-perl.
# Preparing to unpack .../02-libfile-pushd-perl_1.016-1_all.deb ...
# Unpacking libfile-pushd-perl (1.016-1) ...
# Selecting previously unselected package libmodule-build-perl.
# Preparing to unpack .../03-libmodule-build-perl_0.423100-1_all.deb ...
# Adding 'diversion of /usr/bin/config_data to /usr/bin/config_data.diverted by libmodule-build-perl'
# Adding 'diversion of /usr/share/man/man1/config_data.1.gz to /usr/share/man/man1/config_data.diverted.1.gz by libmodule-build-perl'
# Unpacking libmodule-build-perl (0.423100-1) ...
# Selecting previously unselected package liblocal-lib-perl.
# Preparing to unpack .../04-liblocal-lib-perl_2.000028-1_all.deb ...
# Unpacking liblocal-lib-perl (2.000028-1) ...
# Selecting previously unselected package libmodule-cpanfile-perl.
# Preparing to unpack .../05-libmodule-cpanfile-perl_1.1004-1_all.deb ...
# Unpacking libmodule-cpanfile-perl (1.1004-1) ...
# Selecting previously unselected package libparse-pmfile-perl.
# Preparing to unpack .../06-libparse-pmfile-perl_0.43-1_all.deb ...
# Unpacking libparse-pmfile-perl (0.43-1) ...
# Selecting previously unselected package libstring-shellquote-perl.
# Preparing to unpack .../07-libstring-shellquote-perl_1.04-1_all.deb ...
# Unpacking libstring-shellquote-perl (1.04-1) ...
# Selecting previously unselected package cpanminus.
# Preparing to unpack .../08-cpanminus_1.7045-1_all.deb ...
# Unpacking cpanminus (1.7045-1) ...
# Selecting previously unselected package libalgorithm-c3-perl.
# Preparing to unpack .../09-libalgorithm-c3-perl_0.11-1_all.deb ...
# Unpacking libalgorithm-c3-perl (0.11-1) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../10-liburi-perl_5.10-1_all.deb ...
# Unpacking liburi-perl (5.10-1) ...
# Selecting previously unselected package liburi-escape-xs-perl.
# Preparing to unpack .../11-liburi-escape-xs-perl_0.14-1build6_amd64.deb ...
# Unpacking liburi-escape-xs-perl (0.14-1build6) ...
# Selecting previously unselected package libany-uri-escape-perl.
# Preparing to unpack .../12-libany-uri-escape-perl_0.01-3_all.deb ...
# Unpacking libany-uri-escape-perl (0.01-3) ...
# Selecting previously unselected package libb-hooks-op-check-perl.
# Preparing to unpack .../13-libb-hooks-op-check-perl_0.22-1build5_amd64.deb ...
# Unpacking libb-hooks-op-check-perl (0.22-1build5) ...
# Selecting previously unselected package libdynaloader-functions-perl.
# Preparing to unpack .../14-libdynaloader-functions-perl_0.003-1.1_all.deb ...
# Unpacking libdynaloader-functions-perl (0.003-1.1) ...
# Selecting previously unselected package libdevel-callchecker-perl.
# Preparing to unpack .../15-libdevel-callchecker-perl_0.008-1ubuntu4_amd64.deb ...
# Unpacking libdevel-callchecker-perl (0.008-1ubuntu4) ...
# Selecting previously unselected package libparams-classify-perl.
# Preparing to unpack .../16-libparams-classify-perl_0.015-1build5_amd64.deb ...
# Unpacking libparams-classify-perl (0.015-1build5) ...
# Selecting previously unselected package libmodule-runtime-perl.
# Preparing to unpack .../17-libmodule-runtime-perl_0.016-1_all.deb ...
# Unpacking libmodule-runtime-perl (0.016-1) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../18-libtry-tiny-perl_0.31-1_all.deb ...
# Unpacking libtry-tiny-perl (0.31-1) ...
# Selecting previously unselected package libmodule-implementation-perl.
# Preparing to unpack .../19-libmodule-implementation-perl_0.09-1.1_all.deb ...
# Unpacking libmodule-implementation-perl (0.09-1.1) ...
# Selecting previously unselected package libsub-exporter-progressive-perl.
# Preparing to unpack .../20-libsub-exporter-progressive-perl_0.001013-1_all.deb ...
# Unpacking libsub-exporter-progressive-perl (0.001013-1) ...
# Selecting previously unselected package libvariable-magic-perl.
# Preparing to unpack .../21-libvariable-magic-perl_0.62-1build5_amd64.deb ...
# Unpacking libvariable-magic-perl (0.62-1build5) ...
# Selecting previously unselected package libb-hooks-endofscope-perl.
# Preparing to unpack .../22-libb-hooks-endofscope-perl_0.25-1_all.deb ...
# Unpacking libb-hooks-endofscope-perl (0.25-1) ...
# Selecting previously unselected package libclass-c3-perl.
# Preparing to unpack .../23-libclass-c3-perl_0.35-1_all.deb ...
# Unpacking libclass-c3-perl (0.35-1) ...
# Selecting previously unselected package libclass-c3-xs-perl.
# Preparing to unpack .../24-libclass-c3-xs-perl_0.15-1build2_amd64.deb ...
# Unpacking libclass-c3-xs-perl (0.15-1build2) ...
# Selecting previously unselected package libclass-method-modifiers-perl.
# Preparing to unpack .../25-libclass-method-modifiers-perl_2.13-1_all.deb ...
# Unpacking libclass-method-modifiers-perl (2.13-1) ...
# Selecting previously unselected package libclass-xsaccessor-perl.
# Preparing to unpack .../26-libclass-xsaccessor-perl_1.19-3build9_amd64.deb ...
# Unpacking libclass-xsaccessor-perl (1.19-3build9) ...
# Selecting previously unselected package libclone-perl.
# Preparing to unpack .../27-libclone-perl_0.45-1build3_amd64.deb ...
# Unpacking libclone-perl (0.45-1build3) ...
# Selecting previously unselected package libcpan-changes-perl.
# Preparing to unpack .../28-libcpan-changes-perl_0.400002-1.1_all.deb ...
# Unpacking libcpan-changes-perl (0.400002-1.1) ...
# Selecting previously unselected package libparams-util-perl.
# Preparing to unpack .../29-libparams-util-perl_1.102-1build3_amd64.deb ...
# Unpacking libparams-util-perl (1.102-1build3) ...
# Selecting previously unselected package libsub-install-perl.
# Preparing to unpack .../30-libsub-install-perl_0.928-1.1_all.deb ...
# Unpacking libsub-install-perl (0.928-1.1) ...
# Selecting previously unselected package libdata-optlist-perl.
# Preparing to unpack .../31-libdata-optlist-perl_0.112-1_all.deb ...
# Unpacking libdata-optlist-perl (0.112-1) ...
# Selecting previously unselected package libexporter-tiny-perl.
# Preparing to unpack .../32-libexporter-tiny-perl_1.002002-1_all.deb ...
# Unpacking libexporter-tiny-perl (1.002002-1) ...
# Selecting previously unselected package liblist-moreutils-xs-perl.
# Preparing to unpack .../33-liblist-moreutils-xs-perl_0.430-2build2_amd64.deb ...
# Unpacking liblist-moreutils-xs-perl (0.430-2build2) ...
# Selecting previously unselected package liblist-moreutils-perl.
# Preparing to unpack .../34-liblist-moreutils-perl_0.430-2_all.deb ...
# Unpacking liblist-moreutils-perl (0.430-2) ...
# Selecting previously unselected package librole-tiny-perl.
# Preparing to unpack .../35-librole-tiny-perl_2.002004-1_all.deb ...
# Unpacking librole-tiny-perl (2.002004-1) ...
# Selecting previously unselected package libstrictures-perl.
# Preparing to unpack .../36-libstrictures-perl_2.000006-1_all.deb ...
# Unpacking libstrictures-perl (2.000006-1) ...
# Selecting previously unselected package libdata-perl-perl.
# Preparing to unpack .../37-libdata-perl-perl_0.002011-1_all.deb ...
# Unpacking libdata-perl-perl (0.002011-1) ...
# Selecting previously unselected package libmro-compat-perl.
# Preparing to unpack .../38-libmro-compat-perl_0.15-1_all.deb ...
# Unpacking libmro-compat-perl (0.15-1) ...
# Selecting previously unselected package libsub-exporter-perl.
# Preparing to unpack .../39-libsub-exporter-perl_0.988-1_all.deb ...
# Unpacking libsub-exporter-perl (0.988-1) ...
# Selecting previously unselected package libdata-section-perl.
# Preparing to unpack .../40-libdata-section-perl_0.200007-1_all.deb ...
# Unpacking libdata-section-perl (0.200007-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../41-libencode-locale-perl_1.05-1.1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1.1) ...
# Selecting previously unselected package libfile-slurp-perl.
# Preparing to unpack .../42-libfile-slurp-perl_9999.32-1_all.deb ...
# Unpacking libfile-slurp-perl (9999.32-1) ...
# Selecting previously unselected package libio-stringy-perl.
# Preparing to unpack .../43-libio-stringy-perl_2.111-3_all.deb ...
# Unpacking libio-stringy-perl (2.111-3) ...
# Selecting previously unselected package libparams-validate-perl:amd64.
# Preparing to unpack .../44-libparams-validate-perl_1.30-1build3_amd64.deb ...
# Unpacking libparams-validate-perl:amd64 (1.30-1build3) ...
# Selecting previously unselected package libgetopt-long-descriptive-perl.
# Preparing to unpack .../45-libgetopt-long-descriptive-perl_0.109-2_all.deb ...
# Unpacking libgetopt-long-descriptive-perl (0.109-2) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../46-libhtml-tagset-perl_3.20-4_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-4) ...
# Selecting previously unselected package libhtml-parser-perl:amd64.
# Preparing to unpack .../47-libhtml-parser-perl_3.76-1build2_amd64.deb ...
# Unpacking libhtml-parser-perl:amd64 (3.76-1build2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../48-libhttp-date-perl_6.05-1_all.deb ...
# Unpacking libhttp-date-perl (6.05-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../49-libio-html-perl_1.004-2_all.deb ...
# Unpacking libio-html-perl (1.004-2) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../50-liblwp-mediatypes-perl_6.04-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.04-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../51-libhttp-message-perl_6.36-1_all.deb ...
# Unpacking libhttp-message-perl (6.36-1) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../52-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libimport-into-perl.
# Preparing to unpack .../53-libimport-into-perl_1.002005-1_all.deb ...
# Unpacking libimport-into-perl (1.002005-1) ...
# Selecting previously unselected package libmodule-signature-perl.
# Preparing to unpack .../54-libmodule-signature-perl_0.88-1_all.deb ...
# Unpacking libmodule-signature-perl (0.88-1) ...
# Selecting previously unselected package libsub-quote-perl.
# Preparing to unpack .../55-libsub-quote-perl_2.006006-1_all.deb ...
# Unpacking libsub-quote-perl (2.006006-1) ...
# Selecting previously unselected package libmoo-perl.
# Preparing to unpack .../56-libmoo-perl_2.005004-3_all.deb ...
# Unpacking libmoo-perl (2.005004-3) ...
# Selecting previously unselected package libmoox-handlesvia-perl.
# Preparing to unpack .../57-libmoox-handlesvia-perl_0.001009-1_all.deb ...
# Unpacking libmoox-handlesvia-perl (0.001009-1) ...
# Selecting previously unselected package libpackage-stash-perl.
# Preparing to unpack .../58-libpackage-stash-perl_0.39-1_all.deb ...
# Unpacking libpackage-stash-perl (0.39-1) ...
# Selecting previously unselected package libsub-identify-perl.
# Preparing to unpack .../59-libsub-identify-perl_0.14-1build5_amd64.deb ...
# Unpacking libsub-identify-perl (0.14-1build5) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../60-libsub-name-perl_0.26-1build3_amd64.deb ...
# Unpacking libsub-name-perl (0.26-1build3) ...
# Selecting previously unselected package libnamespace-clean-perl.
# Preparing to unpack .../61-libnamespace-clean-perl_0.27-1_all.deb ...
# Unpacking libnamespace-clean-perl (0.27-1) ...
# Selecting previously unselected package libnamespace-autoclean-perl.
# Preparing to unpack .../62-libnamespace-autoclean-perl_0.29-1_all.deb ...
# Unpacking libnamespace-autoclean-perl (0.29-1) ...
# Selecting previously unselected package libnet-libidn-perl.
# Preparing to unpack .../63-libnet-libidn-perl_0.12.ds-3build6_amd64.deb ...
# Unpacking libnet-libidn-perl (0.12.ds-3build6) ...
# Selecting previously unselected package libpackage-stash-xs-perl.
# Preparing to unpack .../64-libpackage-stash-xs-perl_0.29-1build5_amd64.deb ...
# Unpacking libpackage-stash-xs-perl (0.29-1build5) ...
# Selecting previously unselected package libpath-tiny-perl.
# Preparing to unpack .../65-libpath-tiny-perl_0.122-1_all.deb ...
# Unpacking libpath-tiny-perl (0.122-1) ...
# Selecting previously unselected package libperl-dev:amd64.
# Preparing to unpack .../66-libperl-dev_5.34.0-3ubuntu1.5_amd64.deb ...
# Unpacking libperl-dev:amd64 (5.34.0-3ubuntu1.5) ...
# Selecting previously unselected package libpod-markdown-perl.
# Preparing to unpack .../67-libpod-markdown-perl_3.300000-1_all.deb ...
# Unpacking libpod-markdown-perl (3.300000-1) ...
# Selecting previously unselected package libtype-tiny-perl.
# Preparing to unpack .../68-libtype-tiny-perl_1.012004-1_all.deb ...
# Unpacking libtype-tiny-perl (1.012004-1) ...
# Selecting previously unselected package libpod-readme-perl.
# Preparing to unpack .../69-libpod-readme-perl_1.2.3-1_all.deb ...
# Unpacking libpod-readme-perl (1.2.3-1) ...
# Selecting previously unselected package libreadonly-perl.
# Preparing to unpack .../70-libreadonly-perl_2.050-3_all.deb ...
# Unpacking libreadonly-perl (2.050-3) ...
# Selecting previously unselected package libref-util-perl.
# Preparing to unpack .../71-libref-util-perl_0.204-1_all.deb ...
# Unpacking libref-util-perl (0.204-1) ...
# Selecting previously unselected package libref-util-xs-perl.
# Preparing to unpack .../72-libref-util-xs-perl_0.117-1build5_amd64.deb ...
# Unpacking libref-util-xs-perl (0.117-1build5) ...
# Selecting previously unselected package libtext-template-perl.
# Preparing to unpack .../73-libtext-template-perl_1.60-1_all.deb ...
# Unpacking libtext-template-perl (1.60-1) ...
# Selecting previously unselected package libsoftware-license-perl.
# Preparing to unpack .../74-libsoftware-license-perl_0.104001-1_all.deb ...
# Unpacking libsoftware-license-perl (0.104001-1) ...
# Selecting previously unselected package libtype-tiny-xs-perl.
# Preparing to unpack .../75-libtype-tiny-xs-perl_0.022-1build2_amd64.deb ...
# Unpacking libtype-tiny-xs-perl (0.022-1build2) ...
# Selecting previously unselected package libunicode-utf8-perl.
# Preparing to unpack .../76-libunicode-utf8-perl_0.62-1build4_amd64.deb ...
# Unpacking libunicode-utf8-perl (0.62-1build4) ...
# Setting up libhttp-date-perl (6.05-1) ...
# Setting up libfile-slurp-perl (9999.32-1) ...
# Setting up libmodule-cpanfile-perl (1.1004-1) ...
# Setting up libunicode-utf8-perl (0.62-1build4) ...
# Setting up libdynaloader-functions-perl (0.003-1.1) ...
# Setting up libclass-method-modifiers-perl (2.13-1) ...
# Setting up libref-util-xs-perl (0.117-1build5) ...
# Setting up libfile-pushd-perl (1.016-1) ...
# Setting up libclone-perl (0.45-1build3) ...
# Setting up libsub-identify-perl (0.14-1build5) ...
# Setting up libio-stringy-perl (2.111-3) ...
# Setting up libhtml-tagset-perl (3.20-4) ...
# Setting up liblwp-mediatypes-perl (6.04-1) ...
# Setting up libtry-tiny-perl (0.31-1) ...
# Setting up libencode-locale-perl (1.05-1.1) ...
# Setting up libperl-dev:amd64 (5.34.0-3ubuntu1.5) ...
# Setting up libcpan-changes-perl (0.400002-1.1) ...
# Setting up libstring-shellquote-perl (1.04-1) ...
# Setting up libclass-c3-xs-perl (0.15-1build2) ...
# Setting up libsub-install-perl (0.928-1.1) ...
# Setting up libmodule-build-perl (0.423100-1) ...
# Setting up libreadonly-perl (2.050-3) ...
# Setting up libpackage-stash-xs-perl (0.29-1build5) ...
# Setting up libalgorithm-c3-perl (0.11-1) ...
# Setting up libmodule-signature-perl (0.88-1) ...
# Setting up libref-util-perl (0.204-1) ...
# Setting up libvariable-magic-perl (0.62-1build5) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up libio-html-perl (1.004-2) ...
# Setting up libtext-template-perl (1.60-1) ...
# Setting up libb-hooks-op-check-perl (0.22-1build5) ...
# Setting up liblist-moreutils-xs-perl (0.430-2build2) ...
# Setting up libparams-util-perl (1.102-1build3) ...
# Setting up libcpan-distnameinfo-perl (0.12-2.1) ...
# Setting up libsub-exporter-progressive-perl (0.001013-1) ...
# Setting up libsub-name-perl (0.26-1build3) ...
# Setting up libtype-tiny-xs-perl (0.022-1build2) ...
# Setting up liburi-escape-xs-perl (0.14-1build6) ...
# Setting up libcpan-meta-check-perl (0.014-1) ...
# Setting up libparse-pmfile-perl (0.43-1) ...
# Setting up libpath-tiny-perl (0.122-1) ...
# Setting up librole-tiny-perl (2.002004-1) ...
# Setting up libstrictures-perl (2.000006-1) ...
# Setting up libsub-quote-perl (2.006006-1) ...
# Setting up libclass-xsaccessor-perl (1.19-3build9) ...
# Setting up libexporter-tiny-perl (1.002002-1) ...
# Setting up liburi-perl (5.10-1) ...
# Setting up libhttp-message-perl (6.36-1) ...
# Setting up liblist-moreutils-perl (0.430-2) ...
# Setting up libtype-tiny-perl (1.012004-1) ...
# Setting up libclass-c3-perl (0.35-1) ...
# Setting up libdevel-callchecker-perl (0.008-1ubuntu4) ...
# Setting up libany-uri-escape-perl (0.01-3) ...
# Setting up liblocal-lib-perl (2.000028-1) ...
# Setting up libnet-libidn-perl (0.12.ds-3build6) ...
# Setting up libdata-optlist-perl (0.112-1) ...
# Setting up libhtml-parser-perl:amd64 (3.76-1build2) ...
# Setting up libmro-compat-perl (0.15-1) ...
# Setting up libsub-exporter-perl (0.988-1) ...
# Setting up libpod-markdown-perl (3.300000-1) ...
# Setting up libparams-classify-perl (0.015-1build5) ...
# Setting up cpanminus (1.7045-1) ...
# Setting up libmodule-runtime-perl (0.016-1) ...
# Setting up libdata-section-perl (0.200007-1) ...
# Setting up libmodule-implementation-perl (0.09-1.1) ...
# Setting up libpackage-stash-perl (0.39-1) ...
# Setting up libimport-into-perl (1.002005-1) ...
# Setting up libmoo-perl (2.005004-3) ...
# Setting up libdata-perl-perl (0.002011-1) ...
# Setting up libsoftware-license-perl (0.104001-1) ...
# Setting up libparams-validate-perl:amd64 (1.30-1build3) ...
# Setting up libb-hooks-endofscope-perl (0.25-1) ...
# Setting up libmoox-handlesvia-perl (0.001009-1) ...
# Setting up libnamespace-clean-perl (0.27-1) ...
# Setting up libgetopt-long-descriptive-perl (0.109-2) ...
# Setting up libnamespace-autoclean-perl (0.29-1) ...
# Setting up libpod-readme-perl (1.2.3-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# cpanm --notest --installdeps .
# --> Working on .
# Configuring /content/convert-pheno ... OK
# ==> Found dependencies: YAML::XS, Hash::Fold, Mojolicious::Plugin::OpenAPI, Text::Levenshtein::XS, Test::Warn, Sort::Naturally, Devel::Size, DateTime::Format::ISO8601, Test::Deep, XML::Fast, Data::Leaf::Walker, Text::CSV_XS, Mojolicious::Lite, DBD::SQLite, IO::Socket::SSL, DBI, File::ShareDir::ProjectDistDir, Test::Exception, Text::Similarity, JSONLD, JSON::Validator, JSON::XS
# --> Working on YAML::XS
# Fetching http://www.cpan.org/authors/id/T/TI/TINITA/YAML-LibYAML-v0.905.0.tar.gz ... OK
# Configuring YAML-LibYAML-v0.905.0 ... OK
# Building YAML-LibYAML-v0.905.0 ... OK
# Successfully installed YAML-LibYAML-v0.905.0
# --> Working on Hash::Fold
# Fetching http://www.cpan.org/authors/id/C/CH/CHOCOLATE/Hash-Fold-v1.0.0.tar.gz ... OK
# Configuring Hash-Fold-v1.0.0 ... OK
# ==> Found dependencies: Test::Fatal, Throwable::Error
# --> Working on Test::Fatal
# Fetching http://www.cpan.org/authors/id/R/RJ/RJBS/Test-Fatal-0.018.tar.gz ... OK
# Configuring Test-Fatal-0.018 ... OK
# Building Test-Fatal-0.018 ... OK
# Successfully installed Test-Fatal-0.018
# --> Working on Throwable::Error
# Fetching http://www.cpan.org/authors/id/R/RJ/RJBS/Throwable-1.001.tar.gz ... OK
# Configuring Throwable-1.001 ... OK
# ==> Found dependencies: Devel::StackTrace
# --> Working on Devel::StackTrace
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/Devel-StackTrace-2.05.tar.gz ... OK
# Configuring Devel-StackTrace-2.05 ... OK
# Building Devel-StackTrace-2.05 ... OK
# Successfully installed Devel-StackTrace-2.05
# Building Throwable-1.001 ... OK
# Successfully installed Throwable-1.001
# Building Hash-Fold-v1.0.0 ... OK
# Successfully installed Hash-Fold-v1.0.0
# --> Working on Mojolicious::Plugin::OpenAPI
# Fetching http://www.cpan.org/authors/id/J/JH/JHTHORSEN/Mojolicious-Plugin-OpenAPI-5.11.tar.gz ... OK
# Configuring Mojolicious-Plugin-OpenAPI-5.11 ... OK
# ==> Found dependencies: Mojolicious, JSON::Validator
# --> Working on Mojolicious
# Fetching http://www.cpan.org/authors/id/S/SR/SRI/Mojolicious-9.42.tar.gz ... OK
# Configuring Mojolicious-9.42 ... OK
# Building Mojolicious-9.42 ... OK
# Successfully installed Mojolicious-9.42
# --> Working on JSON::Validator
# Fetching http://www.cpan.org/authors/id/J/JH/JHTHORSEN/JSON-Validator-5.15.tar.gz ... OK
# Configuring JSON-Validator-5.15 ... OK
# Building JSON-Validator-5.15 ... OK
# Successfully installed JSON-Validator-5.15
# Building Mojolicious-Plugin-OpenAPI-5.11 ... OK
# Successfully installed Mojolicious-Plugin-OpenAPI-5.11
# --> Working on Text::Levenshtein::XS
# Fetching http://www.cpan.org/authors/id/U/UG/UGEXE/Text-Levenshtein-XS-0.503.tar.gz ... OK
# Configuring Text-Levenshtein-XS-0.503 ... OK
# Building Text-Levenshtein-XS-0.503 ... OK
# Successfully installed Text-Levenshtein-XS-0.503
# --> Working on Test::Warn
# Fetching http://www.cpan.org/authors/id/B/BI/BIGJ/Test-Warn-0.37.tar.gz ... OK
# Configuring Test-Warn-0.37 ... OK
# ==> Found dependencies: Sub::Uplevel
# --> Working on Sub::Uplevel
# Fetching http://www.cpan.org/authors/id/D/DA/DAGOLDEN/Sub-Uplevel-0.2800.tar.gz ... OK
# Configuring Sub-Uplevel-0.2800 ... OK
# Building Sub-Uplevel-0.2800 ... OK
# Successfully installed Sub-Uplevel-0.2800
# Building Test-Warn-0.37 ... OK
# Successfully installed Test-Warn-0.37
# --> Working on Sort::Naturally
# Fetching http://www.cpan.org/authors/id/B/BI/BINGOS/Sort-Naturally-1.03.tar.gz ... OK
# Configuring Sort-Naturally-1.03 ... OK
# Building Sort-Naturally-1.03 ... OK
# Successfully installed Sort-Naturally-1.03
# --> Working on Devel::Size
# Fetching http://www.cpan.org/authors/id/N/NW/NWCLARK/Devel-Size-0.87.tar.gz ... OK
# Configuring Devel-Size-0.87 ... OK
# Building Devel-Size-0.87 ... OK
# Successfully installed Devel-Size-0.87
# --> Working on DateTime::Format::ISO8601
# Fetching http://www.cpan.org/authors/id/T/TI/TIMLEGGE/DateTime-Format-ISO8601-0.19.tar.gz ... OK
# Configuring DateTime-Format-ISO8601-0.19 ... OK
# ==> Found dependencies: Specio, Specio::Library::Builtins, Params::ValidationCompiler, DateTime::Format::Builder, Specio::Exporter, DateTime, Specio::Declare
# --> Working on Specio
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/Specio-0.53.tar.gz ... OK
# Configuring Specio-0.53 ... OK
# ==> Found dependencies: Clone::PP, Eval::Closure, XString
# --> Working on Clone::PP
# Fetching http://www.cpan.org/authors/id/N/NE/NEILB/Clone-PP-1.08.tar.gz ... OK
# Configuring Clone-PP-1.08 ... OK
# Building Clone-PP-1.08 ... OK
# Successfully installed Clone-PP-1.08
# --> Working on Eval::Closure
# Fetching http://www.cpan.org/authors/id/D/DO/DOY/Eval-Closure-0.14.tar.gz ... OK
# Configuring Eval-Closure-0.14 ... OK
# Building Eval-Closure-0.14 ... OK
# Successfully installed Eval-Closure-0.14
# --> Working on XString
# Fetching http://www.cpan.org/authors/id/A/AT/ATOOMIC/XString-0.005.tar.gz ... OK
# Configuring XString-0.005 ... OK
# Building XString-0.005 ... OK
# Successfully installed XString-0.005
# Building Specio-0.53 ... OK
# Successfully installed Specio-0.53
# --> Working on Params::ValidationCompiler
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/Params-ValidationCompiler-0.31.tar.gz ... OK
# Configuring Params-ValidationCompiler-0.31 ... OK
# ==> Found dependencies: Exception::Class
# --> Working on Exception::Class
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/Exception-Class-1.45.tar.gz ... OK
# Configuring Exception-Class-1.45 ... OK
# ==> Found dependencies: Class::Data::Inheritable
# --> Working on Class::Data::Inheritable
# Fetching http://www.cpan.org/authors/id/R/RS/RSHERER/Class-Data-Inheritable-0.10.tar.gz ... OK
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# Configuring Class-Data-Inheritable-0.10 ... OK
# Building Class-Data-Inheritable-0.10 ... OK
# Successfully installed Class-Data-Inheritable-0.10
# Building Exception-Class-1.45 ... OK
# Successfully installed Exception-Class-1.45
# Building Params-ValidationCompiler-0.31 ... OK
# Successfully installed Params-ValidationCompiler-0.31
# --> Working on DateTime::Format::Builder
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/DateTime-Format-Builder-0.83.tar.gz ... OK
# Configuring DateTime-Format-Builder-0.83 ... OK
# ==> Found dependencies: DateTime::Format::Strptime, DateTime
# --> Working on DateTime::Format::Strptime
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/DateTime-Format-Strptime-1.80.tar.gz ... OK
# Configuring DateTime-Format-Strptime-1.80 ... OK
# ==> Found dependencies: DateTime::Locale::Base, DateTime::TimeZone, DateTime::Locale, DateTime::Locale::FromData, DateTime
# --> Working on DateTime::Locale::Base
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/DateTime-Locale-1.45.tar.gz ... OK
# ==> Found dependencies: Dist::CheckConflicts, File::ShareDir::Install
# --> Working on Dist::CheckConflicts
# Fetching http://www.cpan.org/authors/id/D/DO/DOY/Dist-CheckConflicts-0.11.tar.gz ... OK
# Configuring Dist-CheckConflicts-0.11 ... OK
# Building Dist-CheckConflicts-0.11 ... OK
# Successfully installed Dist-CheckConflicts-0.11
# --> Working on File::ShareDir::Install
# Fetching http://www.cpan.org/authors/id/E/ET/ETHER/File-ShareDir-Install-0.14.tar.gz ... OK
# Configuring File-ShareDir-Install-0.14 ... OK
# Building File-ShareDir-Install-0.14 ... OK
# Successfully installed File-ShareDir-Install-0.14
# Configuring DateTime-Locale-1.45 ... OK
# ==> Found dependencies: File::ShareDir
# --> Working on File::ShareDir
# Fetching http://www.cpan.org/authors/id/R/RE/REHSACK/File-ShareDir-1.118.tar.gz ... OK
# Configuring File-ShareDir-1.118 ... OK
# ==> Found dependencies: Class::Inspector
# --> Working on Class::Inspector
# Fetching http://www.cpan.org/authors/id/P/PL/PLICEASE/Class-Inspector-1.36.tar.gz ... OK
# Configuring Class-Inspector-1.36 ... OK
# Building Class-Inspector-1.36 ... OK
# Successfully installed Class-Inspector-1.36
# Building File-ShareDir-1.118 ... OK
# Successfully installed File-ShareDir-1.118
# Building DateTime-Locale-1.45 ... OK
# Successfully installed DateTime-Locale-1.45
# --> Working on DateTime::TimeZone
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/DateTime-TimeZone-2.68.tar.gz ... OK
# Configuring DateTime-TimeZone-2.68 ... OK
# ==> Found dependencies: Class::Singleton
# --> Working on Class::Singleton
# Fetching http://www.cpan.org/authors/id/S/SH/SHAY/Class-Singleton-1.6.tar.gz ... OK
# Configuring Class-Singleton-1.6 ... OK
# Building Class-Singleton-1.6 ... OK
# Successfully installed Class-Singleton-1.6
# Building DateTime-TimeZone-2.68 ... OK
# Successfully installed DateTime-TimeZone-2.68
# --> Working on DateTime
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/DateTime-1.66.tar.gz ... OK
# Configuring DateTime-1.66 ... OK
# Building DateTime-1.66 ... OK
# Successfully installed DateTime-1.66
# Building DateTime-Format-Strptime-1.80 ... OK
# Successfully installed DateTime-Format-Strptime-1.80
# Building DateTime-Format-Builder-0.83 ... OK
# Successfully installed DateTime-Format-Builder-0.83
# Building DateTime-Format-ISO8601-0.19 ... OK
# Successfully installed DateTime-Format-ISO8601-0.19
# --> Working on Test::Deep
# Fetching http://www.cpan.org/authors/id/R/RJ/RJBS/Test-Deep-1.205.tar.gz ... OK
# Configuring Test-Deep-1.205 ... OK
# Building Test-Deep-1.205 ... OK
# Successfully installed Test-Deep-1.205
# --> Working on XML::Fast
# Fetching http://www.cpan.org/authors/id/M/MO/MONS/XML-Fast-0.17.tar.gz ... OK
# Configuring XML-Fast-0.17 ... OK
# Building XML-Fast-0.17 ... OK
# Successfully installed XML-Fast-0.17
# --> Working on Data::Leaf::Walker
# Fetching http://www.cpan.org/authors/id/D/DA/DANBOO/Data-Leaf-Walker-0.21.tar.gz ... OK
# Configuring Data-Leaf-Walker-0.21 ... OK
# Building Data-Leaf-Walker-0.21 ... OK
# Successfully installed Data-Leaf-Walker-0.21
# --> Working on Text::CSV_XS
# Fetching http://www.cpan.org/authors/id/H/HM/HMBRAND/Text-CSV_XS-1.61.tgz ... OK
# Configuring Text-CSV_XS-1.61 ... OK
# Building Text-CSV_XS-1.61 ... OK
# Successfully installed Text-CSV_XS-1.61
# --> Working on DBD::SQLite
# Fetching http://www.cpan.org/authors/id/I/IS/ISHIGAKI/DBD-SQLite-1.78.tar.gz ... OK
# ==> Found dependencies: DBI
# --> Working on DBI
# Fetching http://www.cpan.org/authors/id/H/HM/HMBRAND/DBI-1.647.tgz ... OK
# Configuring DBI-1.647 ... OK
# Building DBI-1.647 ... OK
# Successfully installed DBI-1.647
# Configuring DBD-SQLite-1.78 ... OK
# Building DBD-SQLite-1.78 ... OK
# Successfully installed DBD-SQLite-1.78
# --> Working on IO::Socket::SSL
# Fetching http://www.cpan.org/authors/id/S/SU/SULLR/IO-Socket-SSL-2.098.tar.gz ... OK
# ==> Found dependencies: Net::SSLeay
# --> Working on Net::SSLeay
# Fetching http://www.cpan.org/authors/id/C/CH/CHRISN/Net-SSLeay-1.96.tar.gz ... OK
# Configuring Net-SSLeay-1.96 ... OK
# Building Net-SSLeay-1.96 ... OK
# Successfully installed Net-SSLeay-1.96
# Configuring IO-Socket-SSL-2.098 ... OK
# Building IO-Socket-SSL-2.098 ... OK
# Successfully installed IO-Socket-SSL-2.098
# --> Working on File::ShareDir::ProjectDistDir
# Fetching http://www.cpan.org/authors/id/K/KE/KENTNL/File-ShareDir-ProjectDistDir-1.000009.tar.gz ... OK
# Configuring File-ShareDir-ProjectDistDir-1.000009 ... OK
# ==> Found dependencies: Path::IsDev, Path::FindDev
# --> Working on Path::IsDev
# Fetching http://www.cpan.org/authors/id/K/KE/KENTNL/Path-IsDev-1.001003.tar.gz ... OK
# Configuring Path-IsDev-1.001003 ... OK
# ==> Found dependencies: File::HomeDir, Class::Tiny
# --> Working on File::HomeDir
# Fetching http://www.cpan.org/authors/id/R/RE/REHSACK/File-HomeDir-1.006.tar.gz ... OK
# Configuring File-HomeDir-1.006 ... OK
# ==> Found dependencies: File::Which
# --> Working on File::Which
# Fetching http://www.cpan.org/authors/id/P/PL/PLICEASE/File-Which-1.27.tar.gz ... OK
# Configuring File-Which-1.27 ... OK
# Building File-Which-1.27 ... OK
# Successfully installed File-Which-1.27
# Building File-HomeDir-1.006 ... OK
# Successfully installed File-HomeDir-1.006
# --> Working on Class::Tiny
# Fetching http://www.cpan.org/authors/id/D/DA/DAGOLDEN/Class-Tiny-1.008.tar.gz ... OK
# Configuring Class-Tiny-1.008 ... OK
# Building Class-Tiny-1.008 ... OK
# Successfully installed Class-Tiny-1.008
# Building Path-IsDev-1.001003 ... OK
# Successfully installed Path-IsDev-1.001003
# --> Working on Path::FindDev
# Fetching http://www.cpan.org/authors/id/K/KE/KENTNL/Path-FindDev-v0.5.3.tar.gz ... OK
# Configuring Path-FindDev-v0.5.3 ... OK
# Building Path-FindDev-v0.5.3 ... OK
# Successfully installed Path-FindDev-v0.5.3
# Building File-ShareDir-ProjectDistDir-1.000009 ... OK
# Successfully installed File-ShareDir-ProjectDistDir-1.000009
# --> Working on Test::Exception
# Fetching http://www.cpan.org/authors/id/E/EX/EXODIST/Test-Exception-0.43.tar.gz ... OK
# Configuring Test-Exception-0.43 ... OK
# Building Test-Exception-0.43 ... OK
# Successfully installed Test-Exception-0.43
# --> Working on Text::Similarity
# Fetching http://www.cpan.org/authors/id/T/TP/TPEDERSE/Text-Similarity-0.13.tar.gz ... OK
# Configuring Text-Similarity-0.13 ... OK
# Building Text-Similarity-0.13 ... OK
# Successfully installed Text-Similarity-0.13
# --> Working on JSONLD
# Fetching http://www.cpan.org/authors/id/G/GW/GWILLIAMS/JSONLD-0.006.tar.gz ... OK
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.TextEncoding'
# Configuring JSONLD-0.006 ... OK
# ==> Found dependencies: LWP::Protocol::https, JSON, LWP, Attean, IRI, Test::Modern
# --> Working on LWP::Protocol::https
# Fetching http://www.cpan.org/authors/id/O/OA/OALDERS/LWP-Protocol-https-6.15.tar.gz ... OK
# Configuring LWP-Protocol-https-6.15 ... OK
# ==> Found dependencies: LWP::Protocol::http, LWP::UserAgent, Net::HTTPS
# --> Working on LWP::Protocol::http
# Fetching http://www.cpan.org/authors/id/O/OA/OALDERS/libwww-perl-6.82.tar.gz ... OK
# Configuring libwww-perl-6.82 ... OK
# ==> Found dependencies: HTTP::Cookies, Net::HTTP, WWW::RobotRules, HTTP::Response, File::Listing, HTTP::Request, HTTP::Message, HTTP::Negotiate
# --> Working on HTTP::Cookies
# Fetching http://www.cpan.org/authors/id/O/OA/OALDERS/HTTP-Cookies-6.11.tar.gz ... OK
# Configuring HTTP-Cookies-6.11 ... OK
# ==> Found dependencies: HTTP::Request
# --> Working on HTTP::Request
# Fetching http://www.cpan.org/authors/id/O/OA/OALDERS/HTTP-Message-7.01.tar.gz ... OK
# Configuring HTTP-Message-7.01 ... OK
# ==> Found dependencies: Clone
# --> Working on Clone
# Fetching http://www.cpan.org/authors/id/A/AT/ATOOMIC/Clone-0.50.tar.gz ... OK
# Configuring Clone-0.50 ... OK
# Building Clone-0.50 ... OK
# Successfully installed Clone-0.50 (upgraded from 0.45)
# Building HTTP-Message-7.01 ... OK
# Successfully installed HTTP-Message-7.01 (upgraded from 6.36)
# Building HTTP-Cookies-6.11 ... OK
# Successfully installed HTTP-Cookies-6.11
# --> Working on Net::HTTP
# Fetching http://www.cpan.org/authors/id/O/OA/OALDERS/Net-HTTP-6.24.tar.gz ... OK
# Configuring Net-HTTP-6.24 ... OK
# Building Net-HTTP-6.24 ... OK
# Successfully installed Net-HTTP-6.24
# --> Working on WWW::RobotRules
# Fetching http://www.cpan.org/authors/id/G/GA/GAAS/WWW-RobotRules-6.02.tar.gz ... OK
# Configuring WWW-RobotRules-6.02 ... OK
# Building WWW-RobotRules-6.02 ... OK
# Successfully installed WWW-RobotRules-6.02
# --> Working on File::Listing
# Fetching http://www.cpan.org/authors/id/P/PL/PLICEASE/File-Listing-6.16.tar.gz ... OK
# ...
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemTextContentLanguage'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseVersion'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseLabels'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseConfidences'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemTextContentLanguage'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseVersion'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseLabels'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseConfidences'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.caret'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.visibleIndex'
# /usr/bin/tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.macromates.selectionRange'
# Configuring Module-Pluggable-6.3 ... OK
# Building Module-Pluggable-6.3 ... OK
# Successfully installed Module-Pluggable-6.3
# --> Working on Test::LWP::UserAgent
# Fetching http://www.cpan.org/authors/id/E/ET/ETHER/Test-LWP-UserAgent-0.036.tar.gz ... OK
# Configuring Test-LWP-UserAgent-0.036 ... OK
# ==> Found dependencies: Safe::Isa
# --> Working on Safe::Isa
# Fetching http://www.cpan.org/authors/id/E/ET/ETHER/Safe-Isa-1.000010.tar.gz ... OK
# Configuring Safe-Isa-1.000010 ... OK
# Building Safe-Isa-1.000010 ... OK
# Successfully installed Safe-Isa-1.000010
# Building Test-LWP-UserAgent-0.036 ... OK
# Successfully installed Test-LWP-UserAgent-0.036
# --> Working on Math::Cartesian::Product
# Fetching http://www.cpan.org/authors/id/P/PR/PRBRENAN/Math-Cartesian-Product-1.009.tar.gz ... OK
# Configuring Math-Cartesian-Product-1.009 ... OK
# Building Math-Cartesian-Product-1.009 ... OK
# Successfully installed Math-Cartesian-Product-1.009
# --> Working on Text::CSV
# Fetching http://www.cpan.org/authors/id/I/IS/ISHIGAKI/Text-CSV-2.06.tar.gz ... OK
# Configuring Text-CSV-2.06 ... OK
# Building Text-CSV-2.06 ... OK
# Successfully installed Text-CSV-2.06
# --> Working on MooX::Log::Any
# Fetching http://www.cpan.org/authors/id/C/CA/CAZADOR/MooX-Log-Any-0.004004.tar.gz ... OK
# Configuring MooX-Log-Any-0.004004 ... OK
# ==> Found dependencies: Log::Any
# --> Working on Log::Any
# Fetching http://www.cpan.org/authors/id/P/PR/PREACTION/Log-Any-1.719.tar.gz ... OK
# Configuring Log-Any-1.719 ... OK
# Building Log-Any-1.719 ... OK
# Successfully installed Log-Any-1.719
# Building MooX-Log-Any-0.004004 ... OK
# Successfully installed MooX-Log-Any-0.004004
# --> Working on Test::Roo
# Fetching http://www.cpan.org/authors/id/D/DA/DAGOLDEN/Test-Roo-1.004.tar.gz ... OK
# Configuring Test-Roo-1.004 ... OK
# ==> Found dependencies: MooX::Types::MooseLike::Base
# --> Working on MooX::Types::MooseLike::Base
# Fetching http://www.cpan.org/authors/id/M/MA/MATEU/MooX-Types-MooseLike-0.29.tar.gz ... OK
# Configuring MooX-Types-MooseLike-0.29 ... OK
# Building MooX-Types-MooseLike-0.29 ... OK
# Successfully installed MooX-Types-MooseLike-0.29
# Building Test-Roo-1.004 ... OK
# Successfully installed Test-Roo-1.004
# --> Working on Algorithm::Combinatorics
# Fetching http://www.cpan.org/authors/id/F/FX/FXN/Algorithm-Combinatorics-0.27.tar.gz ... OK
# Configuring Algorithm-Combinatorics-0.27 ... OK
# Building Algorithm-Combinatorics-0.27 ... OK
# Successfully installed Algorithm-Combinatorics-0.27
# --> Working on URI::NamespaceMap
# Fetching http://www.cpan.org/authors/id/K/KJ/KJETILK/URI-NamespaceMap-1.12.tar.gz ... OK
# Configuring URI-NamespaceMap-1.12 ... OK
# ==> Found dependencies: Types::URI
# --> Working on Types::URI
# Fetching http://www.cpan.org/authors/id/T/TO/TOBYINK/Types-URI-0.007.tar.gz ... OK
# Configuring Types-URI-0.007 ... OK
# ==> Found dependencies: Types::Path::Tiny, URI::FromHash, Types::UUID
# --> Working on Types::Path::Tiny
# Fetching http://www.cpan.org/authors/id/D/DA/DAGOLDEN/Types-Path-Tiny-0.006.tar.gz ... OK
# Configuring Types-Path-Tiny-0.006 ... OK
# Building Types-Path-Tiny-0.006 ... OK
# Successfully installed Types-Path-Tiny-0.006
# --> Working on URI::FromHash
# Fetching http://www.cpan.org/authors/id/D/DR/DROLSKY/URI-FromHash-0.05.tar.gz ... OK
# Configuring URI-FromHash-0.05 ... OK
# Building URI-FromHash-0.05 ... OK
# Successfully installed URI-FromHash-0.05
# --> Working on Types::UUID
# Fetching http://www.cpan.org/authors/id/T/TO/TOBYINK/Types-UUID-0.004.tar.gz ... OK
# Configuring Types-UUID-0.004 ... OK
# ==> Found dependencies: UUID::Tiny
# --> Working on UUID::Tiny
# Fetching http://www.cpan.org/authors/id/C/CA/CAUGUSTIN/UUID-Tiny-1.04.tar.gz ... OK
# Configuring UUID-Tiny-1.04 ... OK
# Building UUID-Tiny-1.04 ... OK
# Successfully installed UUID-Tiny-1.04
# Building Types-UUID-0.004 ... OK
# Successfully installed Types-UUID-0.004
# Building Types-URI-0.007 ... OK
# Successfully installed Types-URI-0.007
# Building URI-NamespaceMap-1.12 ... OK
# Successfully installed URI-NamespaceMap-1.12
# --> Working on XML::SAX
# Fetching http://www.cpan.org/authors/id/G/GR/GRANTM/XML-SAX-1.02.tar.gz ... OK
# Configuring XML-SAX-1.02 ... OK
# ==> Found dependencies: XML::NamespaceSupport, XML::SAX::Base
# --> Working on XML::NamespaceSupport
# Fetching http://www.cpan.org/authors/id/P/PE/PERIGRIN/XML-NamespaceSupport-1.12.tar.gz ... OK
# Configuring XML-NamespaceSupport-1.12 ... OK
# Building XML-NamespaceSupport-1.12 ... OK
# Successfully installed XML-NamespaceSupport-1.12
# --> Working on XML::SAX::Base
# Fetching http://www.cpan.org/authors/id/G/GR/GRANTM/XML-SAX-Base-1.09.tar.gz ... OK
# Configuring XML-SAX-Base-1.09 ... OK
# Building XML-SAX-Base-1.09 ... OK
# Successfully installed XML-SAX-Base-1.09
# Building XML-SAX-1.02 ... OK
# Successfully installed XML-SAX-1.02
# --> Working on Text::Table
# Fetching http://www.cpan.org/authors/id/S/SH/SHLOMIF/Text-Table-1.135.tar.gz ... OK
# Configuring Text-Table-1.135 ... OK
# ==> Found dependencies: Text::Aligner
# --> Working on Text::Aligner
# Fetching http://www.cpan.org/authors/id/S/SH/SHLOMIF/Text-Aligner-0.16.tar.gz ... OK
# Configuring Text-Aligner-0.16 ... OK
# Building Text-Aligner-0.16 ... OK
# Successfully installed Text-Aligner-0.16
# Building Text-Table-1.135 ... OK
# Successfully installed Text-Table-1.135
# --> Working on Test::Requires
# Fetching http://www.cpan.org/authors/id/T/TO/TOKUHIROM/Test-Requires-0.11.tar.gz ... OK
# Configuring Test-Requires-0.11 ... OK
# Building Test-Requires-0.11 ... OK
# Successfully installed Test-Requires-0.11
# --> Working on Set::Scalar
# Fetching http://www.cpan.org/authors/id/D/DA/DAVIDO/Set-Scalar-1.29.tar.gz ... OK
# Configuring Set-Scalar-1.29 ... OK
# Building Set-Scalar-1.29 ... OK
# Successfully installed Set-Scalar-1.29
# --> Working on XML::Simple
# Fetching http://www.cpan.org/authors/id/G/GR/GRANTM/XML-Simple-2.25.tar.gz ... OK
# Configuring XML-Simple-2.25 ... OK
# ==> Found dependencies: XML::SAX::Expat
# --> Working on XML::SAX::Expat
# Fetching http://www.cpan.org/authors/id/B/BJ/BJOERN/XML-SAX-Expat-0.51.tar.gz ... OK
# Configuring XML-SAX-Expat-0.51 ... OK
# ==> Found dependencies: XML::Parser
# --> Working on XML::Parser
# Fetching http://www.cpan.org/authors/id/T/TO/TODDR/XML-Parser-2.58.tar.gz ... OK
# Configuring XML-Parser-2.58 ... OK
# Building XML-Parser-2.58 ... OK
# Successfully installed XML-Parser-2.58
# Building XML-SAX-Expat-0.51 ... OK
# Successfully installed XML-SAX-Expat-0.51
# Building XML-Simple-2.25 ... OK
# Successfully installed XML-Simple-2.25
# --> Working on DateTime::Format::W3CDTF
# Fetching http://www.cpan.org/authors/id/G/GW/GWILLIAMS/DateTime-Format-W3CDTF-0.08.tar.gz ... OK
# Configuring DateTime-Format-W3CDTF-0.08 ... OK
# Building DateTime-Format-W3CDTF-0.08 ... OK
# Successfully installed DateTime-Format-W3CDTF-0.08
# Building Attean-0.034 ... OK
# Successfully installed Attean-0.034
# Building JSONLD-0.006 ... OK
# Successfully installed JSONLD-0.006
# --> Working on JSON::XS
# Fetching http://www.cpan.org/authors/id/M/ML/MLEHMANN/JSON-XS-4.04.tar.gz ... OK
# ==> Found dependencies: Canary::Stability
# --> Working on Canary::Stability
# Fetching http://www.cpan.org/authors/id/M/ML/MLEHMANN/Canary-Stability-2013.tar.gz ... OK
# Configuring Canary-Stability-2013 ... OK
# Building Canary-Stability-2013 ... OK
# Successfully installed Canary-Stability-2013
# Configuring JSON-XS-4.04 ... OK
# ==> Found dependencies: common::sense, Types::Serialiser
# --> Working on common::sense
# Fetching http://www.cpan.org/authors/id/M/ML/MLEHMANN/common-sense-3.75.tar.gz ... OK
# Configuring common-sense-3.75 ... OK
# Building common-sense-3.75 ... OK
# Successfully installed common-sense-3.75
# --> Working on Types::Serialiser
# Fetching http://www.cpan.org/authors/id/M/ML/MLEHMANN/Types-Serialiser-1.01.tar.gz ... OK
# Configuring Types-Serialiser-1.01 ... OK
# Building Types-Serialiser-1.01 ... OK
# Successfully installed Types-Serialiser-1.01
# Building JSON-XS-4.04 ... OK
# Successfully installed JSON-XS-4.04
# <== Installed dependencies for .. Finishing.
# 124 distributions installed

# %% [markdown]
# Ok, finally let's run some tests to make sure all works as it should:

# %%
# !make -f makefile.install test
# Out:
# prove -l
# t/00-load.t ........................ ok
# t/01-api-bff-pxf.t ................. ok
# t/02-api-tabular.t ................. ok
# t/03-api-omop.t .................... ok
# t/04-api-stream-omop.t ............. ok
# t/05-errors.t ...................... ok
# t/06-mapping-errors.t .............. ok
# t/07-api-bff-omop.t ................ skipped: share/db/ohdsi.db is required for bff2omop tests
# t/08-jsonld.t ...................... ok
# t/09-pxf-behavior.t ................ ok
# t/10-bff2omop-behavior.t ........... ok
# t/11-mapping-utils.t ............... ok
# t/12-db-similarity.t ............... ok
# t/13-db-sqlite.t ................... ok
# t/14-csvhandler-utils.t ............ ok
# t/15-convertpheno-orchestration.t .. ok
# t/16-omop-behavior.t ............... ok
# t/17-context-bundle.t .............. ok
# t/18-cli-entities.t ................ ok
# t/19-cli-regression.t .............. ok
# t/20-cli-stream-omop.t ............. ok
# t/21-openehr-behavior.t ............ ok
# t/21-search-audit.t ................ ok
# t/22-fileio-gzip.t ................. ok
# t/23-cli-help.t .................... ok
# t/24-tabular-raw-values.t .......... ok
# t/25-json-bridge.t ................. ok
# t/26-omop-biosamples.t ............. ok
# All tests successful.
# Files=28, Tests=552, 84 wallclock secs ( 0.20 usr  0.07 sys + 76.29 cusr  7.37 csys = 83.93 CPU)
# Result: PASS

# %% [markdown]
# The CLI is located at `bin/convert-pheno`. Let's execute it to visualize the help:

# %%
# !bin/convert-pheno -h
# Out:
# Usage:
#   convert-pheno -i <input-type> <infile> -o <output-type> <outfile> [options]
#   convert-pheno -ipxf <infile> -obff <outfile> [options]
#   convert-pheno -ipxf <infile> -obff --entities <list> --out-dir <dir> [options]
#
# Common input flags:
#   -i <type> <file>    Generic input form (pxf|bff|omop|redcap|cdisc|csv|openehr)
#   -ibff <file>      Beacon v2 Models ('individuals' JSON|YAML)
#   -ipxf <file>      Phenopackets v2 (JSON|YAML)
#   -iomop <files...> OMOP-CDM CSV files or PostgreSQL dump
#   -iopenehr <files...>
#                     Experimental openEHR canonical JSON/YAML compositions
#                     (currently EHRbase-oriented; input-only; BFF/PXF output)
#   -iredcap <file>   REDCap export CSV
#   -icdisc <file>    CDISC-ODM XML
#   -icsv <file>      Raw CSV
#
# Common output flags:
#   -o <type> <file>    Generic output form (bff|pxf|omop|csv|jsonf|jsonld)
#   -obff [file]      Beacon-oriented JSON/YAML output
#                     Use -obff FILE for individuals-only BFF output
#                     Use -obff with --entities --out-dir for entity-aware BFF
#   -opxf <file>      Phenopackets v2 output
#   -oomop            OMOP-CDM CSV table output (use with --out-dir)
#   -ocsv <file>      Flattened CSV (with -ibff or -ipxf)
#   -ojsonf <file>    Flattened 1D JSON/YAML (with -ibff or -ipxf)
#   -ojsonld <file>   JSON-LD / YAML-LD (with -ibff or -ipxf)
#
# Output behavior:
#   --out-dir <dir>       Output directory (required for entity-aware BFF mode)
#   --entities <list>     Beacon entities for BFF output [individuals]
#                         Supported: individuals, biosamples, datasets, cohorts
#                         biosamples are emitted from -ipxf when present, or
#                         from -iomop when the SPECIMEN table is provided
#                         datasets and cohorts are synthesized from individuals
#                         Use with -obff and --out-dir
#   --out-name k=file     Override one multi-file output name; repeat as needed
#                         Use entity keys for BFF and table keys for OMOP
#   -O                    Overwrite output file(s)
#
# Mapping and search:
#   --mapping-file <file>           Fields mapping YAML or JSON file
#   --redcap-dictionary|-rcd <file> REDCap data dictionary CSV file
#   --schema-file <file>            Alternative JSON Schema for mapping files
#   --self-validate-schema|-svs     Self-validate the mapping JSON Schema
#                                   (mainly for author/development checks)
#   --search <type>                 Ontology label search mode [exact|mixed|fuzzy]
#                                   Default: exact
#   --text-similarity-method <m>    Token similarity for mixed/fuzzy search
#                                   [cosine|dice], default: cosine
#   --min-text-similarity-score <s> Minimum score for mixed/fuzzy search
#                                   Default: 0.8
#   --levenshtein-weight <w>        Levenshtein weight in fuzzy composite score
#                                   Default: 0.1, range: 0-1
#   --print-hidden-labels|-phl      Preserve original text labels in output
#   --search-audit-tsv <file>       Write a TSV audit of ontology search results
#
# OMOP:
#   --ohdsi-db                      Enable Athena-OHDSI lookup
#   --path-to-ohdsi-db <dir>        Directory containing <ohdsi.db>
#   --omop-tables <list>            Restrict OMOP tables
#   --exposures-file <file>         OMOP concept_id list treated as exposures
#   --stream                        Incremental OMOP processing with single-file
#                                   line-delimited JSON output
#                                   Supports individuals-only <-obff FILE>, or
#                                   entity-aware <-obff --entities individuals
#                                   biosamples --out-dir DIR>
#   --sql2csv                       Print SQL tables instead of converting
#   --max-lines-sql <n>             Maximum SQL lines per table [500]
#
# Other useful options:
#   --default-vital-status <s>   Fallback PXF subject vitalStatus
#                                [ALIVE|DECEASED|UNKNOWN_STATUS]
#                                Used only with PXF output when no source
#                                vitalStatus is available
#   --separator|--sep <char>        Delimiter for CSV input [; for .csv]
#   --username|-u <name>            Override username stored in metadata
#   --test                          Skip time-varying metadata for stable tests
#   --debug <level>                 Print internal request/debug data
#                                   (level >= 2 also prints DB lookup summary)
#   --verbose|-v                    Print progress information
#   --version|-V
#   --help
#   --man
#
# Examples:
#   convert-pheno -i pxf pxf.json -o bff individuals.json
#   convert-pheno -ipxf pxf.json -obff individuals.json
#   convert-pheno -ipxf pxf.json -obff --entities biosamples --out-dir out/
#   convert-pheno -ipxf pxf.json -obff --entities individuals biosamples --out-dir out/ --out-name biosamples=samples.json
#   convert-pheno -ipxf pxf.json -obff --entities individuals datasets cohorts --out-dir out/
#   convert-pheno -icsv data.csv --mapping-file mapping.yaml -obff --entities individuals datasets cohorts --out-dir out/
#   convert-pheno -iomop PERSON.csv CONCEPT.csv SPECIMEN.csv -obff --entities biosamples --out-dir out/
#   convert-pheno -ibff individuals.json -oomop --out-dir omop_out/
#   convert-pheno -ibff individuals.json -oomop --out-dir omop_out/ --out-name PERSON=patients.csv
#   convert-pheno -iomop dump.sql.gz -opxf phenopackets.json.gz --default-vital-status UNKNOWN_STATUS --ohdsi-db
#   convert-pheno -iomop dump.sql.gz -obff individuals.json.gz --stream --ohdsi-db
#   convert-pheno -iomop dump.sql.gz -obff --stream --entities individuals biosamples --out-dir out/ --ohdsi-db
#   convert-pheno -i openehr patient-set.json -o bff individual.json
#   convert-pheno -i openehr patient-set.json -o pxf phenopacket.json
#
# BFF output modes:
#   -obff FILE keeps the individuals-only BFF behavior.
#   -obff --entities ... --out-dir DIR writes one file per requested BFF entity.
#   -oomop --out-dir DIR writes one file per emitted OMOP table.
#   If a PXF input also contains biosamples, convert-pheno warns and preserves them
#   under info.phenopacket.biosamples unless --entities is used.
#   PXF output still defaults subject.vitalStatus to ALIVE unless a preserved
#   source vitalStatus or --default-vital-status is available.
#   openEHR input support is currently experimental and limited to BFF or PXF output.
#
# Docs:
#   Site:  https://cnag-biomedical-informatics.github.io/convert-pheno
#   CLI:   https://cnag-biomedical-informatics.github.io/convert-pheno/use-as-a-command-line-interface/
#   Install:
#          https://cnag-biomedical-informatics.github.io/convert-pheno/download-and-installation/

# %% [markdown]
# # Converting OMOP CDM data to Beacon v2

# %% [markdown]
# For the explanation we will be using the synthtic data [EUNOMIA](https://ohdsi.github.io/Eunomia). These data were imported into a PostgreSQL instance and then exported as a single [text file](/content/convert-pheno/t/omop2bff/in/omop_cdm_eunomia.sql).
#
# Note that `Convert-Pheno` also allows to perform the same operations using separated CSV files (one for each table) as input.

# %% [markdown]
# ## OMOP CDM to BFF

# %% [markdown]
# Here we'll convert the OMOP CDM export to Beacon Friendly Format (BFF). BFF is the data exchange format (`JSON`) of the Beacon v2 Models.
#
# From now on. we'll be storing the files in the directory `/content`.

# %% [markdown]
# ### No-stream mode (default)

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals.json --out-dir /content

# %% [markdown]
# Uhmm...no output on the screen, what happened?
#
# Well, this is actually a sign that the program worked fine. No news is good news.
#
# A new file was created at `/content/omop_individuals.json`.
#
# *Note:* You can access the directory `/content` by clicking in the folder icon on the left side navigation menu.
#
# If you want to re-create a file and the script says the file exists you can use the option `-O` (overwrite).
#
# Let's use the Linux command `head` see the first 10 lines of the file.

# %%
# !head /content/omop_individuals.json
# Out:
# [
# {
#    "diseases" : [
#       {
#          "_info" : {
#             "CONDITION_OCCURRENCE" : {
#                "OMOP_columns" : {
#                   "condition_concept_id" : 40479768,
#                   "condition_end_date" : "1981-09-16",
#                   "condition_end_datetime" : "1981-09-16 00:00:00",

# %% [markdown]
# Browsing JSON text files can be a bit cumbersome. We will install the awesome utility [jq](https://stedolan.github.io/jq) to extract some information.

# %%
# !apt install jq
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# jq is already the newest version (1.6-2.1ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %% [markdown]
# Great! The created JSON file consists of an array of objects, each object being an invdividual. Now we we'll check the property "id" for all individuals, but we will only display the first 5.

# %%
# !jq '.[].id' /content/omop_individuals.json | head -5
# Out:
# "1"
# "2"
# "3"
# "5"
# "6"

# %% [markdown]
# Great!
#
# Ok, let's use `jq` again to fetch the `sex` property from each individual and count how many we have from each.

# %%
# !jq '.[].sex.label' /content/omop_individuals.json | sort | uniq -c
# Out:
#     256 "Female"
#     244 "Male"

# %% [markdown]
# Let's complicate a bit the query. Let's find out the disease ontology-term id for the 1st item inside `diseases`.

# %%
# !jq '.[].diseases[0].diseaseCode.id' /content/omop_individuals.json | sort | uniq -c | sort -nr -k1
# Out:
#     422 null
#      24 "SNOMED:444814009"
#      11 "SNOMED:195662009"
#       8 "SNOMED:10509002"
#       4 "SNOMED:43878008"
#       3 "SNOMED:62106007"
#       3 "SNOMED:40055000"
#       2 "SNOMED:74474003"
#       2 "SNOMED:70704007"
#       2 "SNOMED:65363002"
#       2 "SNOMED:444470001"
#       2 "SNOMED:39848009"
#       2 "SNOMED:396275006"
#       2 "SNOMED:301011002"
#       1 "SNOMED:75498004"
#       1 "SNOMED:410429000"
#       1 "SNOMED:403191005"
#       1 "SNOMED:370247008"
#       1 "SNOMED:36971009"
#       1 "SNOMED:284549007"
#       1 "SNOMED:283385000"
#       1 "SNOMED:26929004"
#       1 "SNOMED:263102004"
#       1 "SNOMED:16114001"
#       1 "SNOMED:128613002"

# %% [markdown]
# Ok. SO we see we have a bunch of `null`values, and then 2-3 predominant conditions.
#
# Let's now use the flag `--verbose` to get more information on the job itself:

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals.json --out-dir /content --verbose -O
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# Writing </content/omop_individuals.json> file
#
# > Param: --max-lines-sql = 500
# > Mode : --no-stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <CONDITION_OCCURRENCE> in memory...
# ==============
# Rows read(total): 500
#
# Loading <DRUG_EXPOSURE> in memory...
# ==============
# Rows read(total): 500
#
# Loading <MEASUREMENT> in memory...
# ==============
# Rows read(total): 500
#
# Loading <OBSERVATION> in memory...
# ==============
# Rows read(total): 500
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 500
#
# Loading <PROCEDURE_OCCURRENCE> in memory...
# ==============
# Rows read(total): 500
#
# Loading <SPECIMEN> in memory...
# ==============
# Rows read(total): 0
#
# Loading <VISIT_OCCURRENCE> in memory...
# ==============
# Rows read(total): 500
#
# ==========================
# Rows read (sqldump-total): 3945
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.0048 GB
#
# > Parameter --max-lines-sql set to: 500
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(VISIT_OCCURRENCE)):   0.0007 GB
#
# ***RAM Usage***(transpose_omop_data_structure):   0.0041 GB
#
# ==============
# Individuals total:     500
#
# All done!

# %% [markdown]
# Let's take a look to the data with `pandas`. We'll be displaying only the 1st individual.

# %%
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter()

# Import json
df = pd.read_json('/content/omop_individuals.json')
df.head(1)
# Out:
#                                             diseases  \
# 0  [{'_info': {'CONDITION_OCCURRENCE': {'OMOP_col...
#
#                                  ethnicity  \
# 0  {'id': 'NCIT:C41261', 'label': 'White'}
#
#                             geographicOrigin  id  \
# 0  {'id': 'NCIT:C43857', 'label': 'Italian'}   1
#
#                                                 info  \
# 0  {'PERSON': {'OMOP_columns': {'birth_datetime':...
#
#                            interventionsOrProcedures  \
# 0  [{'_info': {'PROCEDURE_OCCURRENCE': {'OMOP_col...
#
#                                       sex phenotypicFeatures treatments  \
# 0  {'id': 'NCIT:C20197', 'label': 'Male'}                NaN        NaN
#
#   measures
# 0      NaN

# %% [markdown]
# Now we'll run `Convert-Pheno` again but we'll ask `Convert-Pheno` to print the SQL tables as `csv` files.
#
# We'll be using the flag:
#
# * `--sql2csv`

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals.json --out-dir /content --sql2csv --verbose -O
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# Writing </content/omop_individuals.json> file
#
# > Param: --max-lines-sql = 500
# > Mode : --no-stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <CONDITION_OCCURRENCE> in memory...
# ==============
# Rows read(total): 500
#
# Loading <DRUG_EXPOSURE> in memory...
# ==============
# Rows read(total): 500
#
# Loading <MEASUREMENT> in memory...
# ==============
# Rows read(total): 500
#
# Loading <OBSERVATION> in memory...
# ==============
# Rows read(total): 500
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 500
#
# Loading <PROCEDURE_OCCURRENCE> in memory...
# ==============
# Rows read(total): 500
#
# Loading <SPECIMEN> in memory...
# ==============
# Rows read(total): 0
#
# Loading <VISIT_OCCURRENCE> in memory...
# ==============
# Rows read(total): 500
#
# ==========================
# Rows read (sqldump-total): 3945
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.0048 GB
#
# > Parameter --max-lines-sql set to: 500
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(VISIT_OCCURRENCE)):   0.0007 GB
#
# ***RAM Usage***(transpose_omop_data_structure):   0.0041 GB
#
# ==============
# Individuals total:     500
#
# All done!

# %% [markdown]
# And voila...now you have a bunch of `csv` files inside `/content`

# %% [markdown]
# The tables `PERSON` and `CONCEPT` are always read, but it is possible to process specific tables by using the option `--omop-tables`. Let's process only the table `DRUG_EXPOSURE`:

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals_drug_exposure.json --omop-tables DRUG_EXPOSURE --out-dir /content --verbose
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# Writing </content/omop_individuals_drug_exposure.json> file
#
# > Param: --max-lines-sql = 500
# > Mode : --no-stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <DRUG_EXPOSURE> in memory...
# ==============
# Rows read(total): 500
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 500
#
# ==========================
# Rows read (sqldump-total): 1445
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.0019 GB
#
# > Parameter --max-lines-sql set to: 500
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(transpose_omop_data_structure):   0.0016 GB
#
# ==============
# Individuals total:     500
#
# All done!

# %% [markdown]
# Finally, you may have noticed that we only had 500 individuals in our examples. This is deliberate. We set a limit to avoid people crashing their machines while testing the code. If you want to convert your whole OMOP CDM export, use the option `-max-lines-sql` and set it to, say, 99999, like this:

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals_drug_exposure.json --omop-tables DRUG_EXPOSURE -O --out-dir /content --verbose -max-lines-sql 99999
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# Writing </content/omop_individuals_drug_exposure.json> file
#
# > Param: --max-lines-sql = 99999
# > Mode : --no-stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <DRUG_EXPOSURE> in memory...
# Rows read: 10000
# Rows read: 20000
# Rows read: 30000
# Rows read: 40000
# Rows read: 50000
# Rows read: 60000
# ==============
# Rows read(total): 67707
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 2694
#
# ==========================
# Rows read (sqldump-total): 70846
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.1188 GB
#
# > Parameter --max-lines-sql set to: 99999
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(transpose_omop_data_structure):   0.1191 GB
#
# ==============
# Individuals total:     2694
#
# All done!

# %% [markdown]
# ### Stream mode

# %% [markdown]
# In the default mode `--no-stream`, all the data are loaded into RAM and then consolidated into a single JSON file.
#
# However, if your OMOP CDM is large, this can be problematic because the required amount of RAM may exceed your hardware specifications. In such cases, we recommend using `--stream`, which enables processing your OMOP CDM input data line by line.
#
# Note, however, that `CONCEPT`, `PERSON` and `VISIT_OCCURRENCE` tables have to be loaded in RAM memory.

# %% [markdown]
#  First we will perform a basic conversion. This one will create an error on purpose, due to the fact that the `CONCEPT` table is also read line-by-line and the default value of `-max-lines-sql 500` does not capture `concept_id` outside this range.

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals_stream.json --out-dir /content -O -verbose -stream
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# > Param: --max-lines-sql = 500
# > Mode : --stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 500
#
# Loading <VISIT_OCCURRENCE> in memory...
# ==============
# Rows read(total): 500
#
# ==========================
# Rows read (sqldump-total): 1445
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.0016 GB
#
# > Parameter --max-lines-sql set to: 500
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(PERSON)):   0.0007 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(VISIT_OCCURRENCE)):   0.0007 GB
#
# Processing table <CONDITION_OCCURRENCE> line-by-line...
# Error: Error: We could not find person_id:608. Try increasing the #lines with --max-lines-sql

# %% [markdown]
# Thus, we add the option `-max-lines-sql 99999` and re-run:

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals_stream.json --out-dir /content -O -verbose -stream -max-lines-sql 99999
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# > Param: --max-lines-sql = 99999
# > Mode : --stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 2694
#
# Loading <VISIT_OCCURRENCE> in memory...
# ==============
# Rows read(total): 1037
#
# ==========================
# Rows read (sqldump-total): 4176
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.0051 GB
#
# > Parameter --max-lines-sql set to: 99999
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(PERSON)):   0.0037 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(VISIT_OCCURRENCE)):   0.0014 GB
#
# Processing table <CONDITION_OCCURRENCE> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# Rows processed: 40000
# Rows processed: 50000
# Rows processed: 60000
# ==============
# Rows processed(total): 65332
#
# Processing table <PROCEDURE_OCCURRENCE> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# ==============
# Rows processed(total): 37409
#
# Processing table <MEASUREMENT> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# Rows processed: 40000
# ==============
# Rows processed(total): 44053
#
# Processing table <OBSERVATION> line-by-line...
# ==============
# Rows processed(total): 1477
#
# Processing table <DRUG_EXPOSURE> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# Rows processed: 40000
# Rows processed: 50000
# Rows processed: 60000
# ==============
# Rows processed(total): 67707
#
# Processing table <SPECIMEN> line-by-line...
# ==============
# Rows processed(total): 0
#
# All done!

# %% [markdown]
# Ok, let's take a look to the data:

# %%
# !head -5 /content/omop_individuals_stream.json
# Out:
# {"diseases":[{"_info":{"CONDITION_OCCURRENCE":{"OMOP_columns":{"condition_concept_id":4112343,"condition_end_date":"2015-10-14","condition_end_datetime":"2015-10-14 00:00:00","condition_occurrence_id":4483,"condition_source_concept_id":4112343,"condition_source_value":195662009,"condition_start_date":"2015-10-02","condition_start_datetime":"2015-10-02 00:00:00","condition_status_concept_id":0,"condition_status_source_value":null,"condition_type_concept_id":32020,"person_id":"263","provider_id":"\\N","stop_reason":null,"visit_detail_id":0,"visit_occurrence_id":17479}}},"ageOfOnset":{"age":{"iso8601duration":"P61Y"}},"diseaseCode":{"id":"SNOMED:195662009","label":"Acute viral pharyngitis"},"stage":{"id":"NCIT:C126101","label":"Not Available"}}],"ethnicity":{"id":"NCIT:C41261","label":"White"},"geographicOrigin":{"id":"NCIT:C43853","label":"English"},"id":"263","info":{"PERSON":{"OMOP_columns":{"birth_datetime":"1954-06-20 00:00:00","care_site_id":"\\N","day_of_birth":20,"ethnicity_concept_id":0,"ethnicity_source_concept_id":0,"ethnicity_source_value":"english","gender_concept_id":8507,"gender_source_concept_id":0,"gender_source_value":"M","location_id":"\\N","month_of_birth":6,"person_id":263,"person_source_value":"0beb03f1-8596-4ffb-b4b3-acc5faede0d4","provider_id":"\\N","race_concept_id":8527,"race_source_concept_id":0,"race_source_value":"white","year_of_birth":1954}},"convertPheno":{"beaconSchemaVersion":"2.0.0","cwd":"/content/convert-pheno","hostname":"0c9386e17a7d","id":"177705016021622","threadshost":2,"user":"dummy-user","username":"dummy-user","version":"0.31_1"},"dateOfBirth":"1954-06-20T00:00:00Z"},"sex":{"id":"NCIT:C20197","label":"Male"}}
# {"diseases":[{"_info":{"CONDITION_OCCURRENCE":{"OMOP_columns":{"condition_concept_id":192671,"condition_end_date":"\\N","condition_end_datetime":"\\N","condition_occurrence_id":4657,"condition_source_concept_id":35208414,"condition_source_value":"K92.2","condition_start_date":"2011-10-10","condition_start_datetime":"2011-10-10 00:00:00","condition_status_concept_id":0,"condition_status_source_value":null,"condition_type_concept_id":32020,"person_id":"273","provider_id":"\\N","stop_reason":null,"visit_detail_id":0,"visit_occurrence_id":18192}}},"_visit":{"_info":{"VISIT_OCCURRENCE":{"OMOP_columns":{"admitting_source_concept_id":0,"admitting_source_value":null,"care_site_id":"\\N","discharge_to_concept_id":0,"discharge_to_source_value":null,"person_id":273,"preceding_visit_occurrence_id":18233,"provider_id":"\\N","visit_concept_id":9201,"visit_end_date":"2011-10-11","visit_end_datetime":"2011-10-11 00:00:00","visit_occurrence_id":18192,"visit_source_concept_id":0,"visit_source_value":"ad268ec8-d670-4ad8-8009-704a4ece6cd6","visit_start_date":"2011-10-10","visit_start_datetime":"2011-10-10 00:00:00","visit_type_concept_id":44818517}}},"concept":{"id":"Visit:IP","label":"Inpatient Visit"},"end_date":"2011-10-11T00:00:00Z","id":"18192","occurrence_id":18192,"start_date":"2011-10-10T00:00:00Z","type":{"id":"Visit Type:OMOP4822465","label":"Visit derived from encounter on claim"}},"ageOfOnset":{"age":{"iso8601duration":"P36Y"}},"diseaseCode":{"id":"SNOMED:74474003","label":"Gastrointestinal hemorrhage"},"stage":{"id":"NCIT:C126101","label":"Not Available"}}],"id":"273","info":{"PERSON":{"OMOP_columns":{"birth_datetime":"1975-09-14 00:00:00","gender_concept_id":8507,"person_id":273}},"convertPheno":{"beaconSchemaVersion":"2.0.0","cwd":"/content/convert-pheno","hostname":"0c9386e17a7d","id":"177705016021622","threadshost":2,"user":"dummy-user","username":"dummy-user","version":"0.31_1"},"dateOfBirth":"1975-09-14T00:00:00Z"},"sex":{"id":"NCIT:C20197","label":"Male"}}
# {"diseases":[{"_info":{"CONDITION_OCCURRENCE":{"OMOP_columns":{"condition_concept_id":28060,"condition_end_date":"1984-02-25","condition_end_datetime":"1984-02-25 00:00:00","condition_occurrence_id":4815,"condition_source_concept_id":28060,"condition_source_value":43878008,"condition_start_date":"1984-02-15","condition_start_datetime":"1984-02-15 00:00:00","condition_status_concept_id":0,"condition_status_source_value":null,"condition_type_concept_id":32020,"person_id":"283","provider_id":"\\N","stop_reason":null,"visit_detail_id":0,"visit_occurrence_id":18859}}},"ageOfOnset":{"age":{"iso8601duration":"P3Y"}},"diseaseCode":{"id":"SNOMED:43878008","label":"Streptococcal sore throat"},"stage":{"id":"NCIT:C126101","label":"Not Available"}}],"id":"283","info":{"PERSON":{"OMOP_columns":{"birth_datetime":"1980-09-01 00:00:00","gender_concept_id":8532,"person_id":283}},"convertPheno":{"beaconSchemaVersion":"2.0.0","cwd":"/content/convert-pheno","hostname":"0c9386e17a7d","id":"177705016021622","threadshost":2,"user":"dummy-user","username":"dummy-user","version":"0.31_1"},"dateOfBirth":"1980-09-01T00:00:00Z"},"sex":{"id":"NCIT:C16576","label":"Female"}}
# {"diseases":[{"_info":{"CONDITION_OCCURRENCE":{"OMOP_columns":{"condition_concept_id":378001,"condition_end_date":"2005-12-07","condition_end_datetime":"2005-12-07 00:00:00","condition_occurrence_id":4981,"condition_source_concept_id":378001,"condition_source_value":62106007,"condition_start_date":"2005-11-07","condition_start_datetime":"2005-11-07 00:00:00","condition_status_concept_id":0,"condition_status_source_value":null,"condition_type_concept_id":32020,"person_id":"293","provider_id":"\\N","stop_reason":null,"visit_detail_id":0,"visit_occurrence_id":19515}}},"ageOfOnset":{"age":{"iso8601duration":"P41Y"}},"diseaseCode":{"id":"SNOMED:62106007","label":"Concussion with no loss of consciousness"},"stage":{"id":"NCIT:C126101","label":"Not Available"}}],"id":"293","info":{"PERSON":{"OMOP_columns":{"birth_datetime":"1964-10-13 00:00:00","gender_concept_id":8507,"person_id":293}},"convertPheno":{"beaconSchemaVersion":"2.0.0","cwd":"/content/convert-pheno","hostname":"0c9386e17a7d","id":"177705016021622","threadshost":2,"user":"dummy-user","username":"dummy-user","version":"0.31_1"},"dateOfBirth":"1964-10-13T00:00:00Z"},"sex":{"id":"NCIT:C20197","label":"Male"}}
# {"diseases":[{"_info":{"CONDITION_OCCURRENCE":{"OMOP_columns":{"condition_concept_id":257012,"condition_end_date":"1974-11-05","condition_end_datetime":"1974-11-05 00:00:00","condition_occurrence_id":5153,"condition_source_concept_id":257012,"condition_source_value":40055000,"condition_start_date":"1974-07-30","condition_start_datetime":"1974-07-30 00:00:00","condition_status_concept_id":0,"condition_status_source_value":null,"condition_type_concept_id":32020,"person_id":"304","provider_id":"\\N","stop_reason":null,"visit_detail_id":0,"visit_occurrence_id":20239}}},"ageOfOnset":{"age":{"iso8601duration":"P18Y"}},"diseaseCode":{"id":"SNOMED:40055000","label":"Chronic sinusitis"},"stage":{"id":"NCIT:C126101","label":"Not Available"}}],"id":"304","info":{"PERSON":{"OMOP_columns":{"birth_datetime":"1956-05-07 00:00:00","gender_concept_id":8507,"person_id":304}},"convertPheno":{"beaconSchemaVersion":"2.0.0","cwd":"/content/convert-pheno","hostname":"0c9386e17a7d","id":"177705016021622","threadshost":2,"user":"dummy-user","username":"dummy-user","version":"0.31_1"},"dateOfBirth":"1956-05-07T00:00:00Z"},"sex":{"id":"NCIT:C20197","label":"Male"}}

# %% [markdown]
# This time we have one JSON object per line, and the data are not consolidated per individual. If your goal is to ingest these data into `MongoDB`, this is a cosmetic concern as the joining will be carried out by the field `id`.

# %% [markdown]
# Anything said for the `--no-stream` mode works here. Let's do a conversion using only one table.

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals_drug_exposure_stream.json --omop-tables DRUG_EXPOSURE -O --out-dir /content --verbose -max-lines-sql 99999 --stream
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# > Param: --max-lines-sql = 99999
# > Mode : --stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 2694
#
# Loading <VISIT_OCCURRENCE> in memory...
# ==============
# Rows read(total): 1037
#
# ==========================
# Rows read (sqldump-total): 4176
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.0051 GB
#
# > Parameter --max-lines-sql set to: 99999
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(PERSON)):   0.0037 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(VISIT_OCCURRENCE)):   0.0014 GB
#
# Processing table <DRUG_EXPOSURE> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# Rows processed: 40000
# Rows processed: 50000
# Rows processed: 60000
# ==============
# Rows processed(total): 67707
#
# All done!

# %% [markdown]
# # Analyzing the completeness of the conversion

# %% [markdown]
# We are going to use some scripts to analyze the completeness of the conversion. We will start by counting the number of entries of each CSV.
#
# First, we will run `Convert-Pheno`making sure that it includes all PosgreSQL rows in the conversion:

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals_completeness.json --out-dir /content --sql2csv --verbose -O -max-lines-sql 99999
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# Writing </content/omop_individuals_completeness.json> file
#
# > Param: --max-lines-sql = 99999
# > Mode : --no-stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <CONDITION_OCCURRENCE> in memory...
# Rows read: 10000
# Rows read: 20000
# Rows read: 30000
# Rows read: 40000
# Rows read: 50000
# Rows read: 60000
# ==============
# Rows read(total): 65332
#
# Loading <DRUG_EXPOSURE> in memory...
# Rows read: 10000
# Rows read: 20000
# Rows read: 30000
# Rows read: 40000
# Rows read: 50000
# Rows read: 60000
# ==============
# Rows read(total): 67707
#
# Loading <MEASUREMENT> in memory...
# Rows read: 10000
# Rows read: 20000
# Rows read: 30000
# Rows read: 40000
# ==============
# Rows read(total): 44053
#
# Loading <OBSERVATION> in memory...
# ==============
# Rows read(total): 1477
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 2694
#
# Loading <PROCEDURE_OCCURRENCE> in memory...
# Rows read: 10000
# Rows read: 20000
# Rows read: 30000
# ==============
# Rows read(total): 37409
#
# Loading <SPECIMEN> in memory...
# ==============
# Rows read(total): 0
#
# Loading <VISIT_OCCURRENCE> in memory...
# ==============
# Rows read(total): 1037
#
# ==========================
# Rows read (sqldump-total): 220154
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.2941 GB
#
# > Parameter --max-lines-sql set to: 99999
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(VISIT_OCCURRENCE)):   0.0014 GB
#
# ***RAM Usage***(transpose_omop_data_structure):   0.2940 GB
#
# ==============
# Individuals total:     2694
#
# All done!

# %% [markdown]
# Let's do a rough count using `Bash` commands:

# %%
# !wc -l /content/*csv
# Out:
#      446 /content/CONCEPT.csv
#    65333 /content/CONDITION_OCCURRENCE.csv
#    67708 /content/DRUG_EXPOSURE.csv
#    44054 /content/MEASUREMENT.csv
#     1478 /content/OBSERVATION.csv
#     2695 /content/PERSON.csv
#    37410 /content/PROCEDURE_OCCURRENCE.csv
#        1 /content/SPECIMEN.csv
#     1038 /content/VISIT_OCCURRENCE.csv
#   220163 total

# %% [markdown]
# Well, that worked but the stats are a bit simple...
# Note that each CSV has a header so the total number of entries is n-1.
#
# Let's continue using `Bash` to perform a more sophisticated processing. In the cells below, first we create on-the-fly a the script named `count_lines.sh` and then we run it.

# %%
# @title See code
# %%bash
# Define the script
cat << 'EOF' > count_lines.sh
#!/bin/bash

# Check if at least one file is provided
if [ "$#" -eq 0 ]; then
    echo "Usage: $0 file1 file2 ..."
    exit 1
fi

# Loop through each provided file
for file in "$@"; do
    # Get the basename of the file without the extension
    base=$(basename "$file" | cut -d. -f1)

    # Count the number of lines excluding the header
    line_count=$(sed 1d "$file" | wc -l)

    # Output the basename and line count separated by a tab
    echo -e "${base}\t${line_count}"
done
EOF

# Make the script executable
chmod +x count_lines.sh

# %%
# !./count_lines.sh /content/*csv > /content/csv_stats.txt
# !cat /content/csv_stats.txt
# Out:
# CONCEPT	445
# CONDITION_OCCURRENCE	65332
# DRUG_EXPOSURE	67707
# MEASUREMENT	44053
# OBSERVATION	1477
# PERSON	2694
# PROCEDURE_OCCURRENCE	37409
# SPECIMEN	0
# VISIT_OCCURRENCE	1037

# %% [markdown]
# Great, now let's count how many of these rows were converted into BFF. Again, we will create a script on the fly `process_json.sh` and then we execute it.

# %%
# @title See code
# %%bash
# Define the script
cat << 'EOF' > process_json.sh
#!/bin/bash

# Check if input file is provided
if [ "$#" -ne 1 ]; then
    echo "Usage: $0 input_file"
    exit 1
fi

input=$1

# Loop through the terms and process the JSON input
for term in diseases exposures id interventionsOrProcedures measures phenotypicFeatures treatments
do
  echo -en "$term\t"
  if [ "$term" = "id" ]; then
    # Count 'id' only at the top level
    jq -c '[.[] | select(has("id"))] | length' < $input
  else
    # Checking for presence of the term and if it's an array; count elements
    jq -c '[.[] | .["'"$term"'"]? | if type == "array" then . | length else 0 end] | add' < $input
  fi
done
EOF

# Make the script executable
chmod +x process_json.sh

# %%
# !./process_json.sh /content/omop_individuals_completeness.json > /content/json_stats.txt
# !cat /content/json_stats.txt
# Out:
# diseases	65332
# exposures	0
# id	2694
# interventionsOrProcedures	37409
# measures	44053
# phenotypicFeatures	1477
# treatments	67707

# %% [markdown]
# Ok, now let's create a table like that of the paper. We'll be using a `Python`script:

# %%
# @title See code
# Define the script with an output mode switch
# Define the script content
script_content = """
import sys
from IPython.display import Markdown, display

# Ensure the correct number of arguments are provided
if len(sys.argv) != 4:
    print("Usage: python script.py <json> <csv> <mode[display|raw]>")
    sys.exit(1)

# Read contents from the files specified in the arguments
file1_path = sys.argv[1]
file2_path = sys.argv[2]
mode = sys.argv[3]  # 'raw' or 'display'

with open(file1_path, 'r') as file:
    file1_content = file.read()

with open(file2_path, 'r') as file:
    file2_content = file.read()

# Read and parse file1
bff_dict = {}
for line in file1_content.strip().split('\\n'):
    key, value = line.split('\\t')
    bff_dict[key] = int(value)

# Read and parse file2
csv_dict = {}
for line in file2_content.strip().split('\\n'):
    key, value = line.split('\\t')
    csv_dict[key] = int(value)

# Define the mapping from OMOP-CDM table names to BFF term names
mapping = {
    "CONDITION_OCCURRENCE": "diseases",
    "DRUG_EXPOSURE": "treatments",
    "MEASUREMENT": "measures",
    "OBSERVATION": "phenotypicFeatures",
    "PERSON": "id",
    "PROCEDURE_OCCURRENCE": "interventionsOrProcedures",
    "CONCEPT": None,
    "VISIT_OCCURRENCE": None
}

# Generate the markdown table
markdown_table = "| OMOP-CDM Table          | BFF Term                     | # Rows in CSV | # Objects in BFF | Completeness (%) |\\n"
markdown_table += "|-------------------------|------------------------------|---------------|------------------|------------------|\\n"

for table, csv_rows in csv_dict.items():
    bff_term = mapping.get(table, "-")
    bff_rows = bff_dict.get(bff_term, 0) if bff_term else "-"

    # Format only the # Rows in CSV and # Objects in BFF columns with thousands separators
    csv_rows_formatted = f"{csv_rows:,}"
    bff_rows_formatted = f"{bff_rows:,}" if isinstance(bff_rows, int) else "-"
    completeness = f"{((bff_rows / csv_rows) * 100):.0f}" if isinstance(bff_rows, int) and bff_rows > 0 else "-"

    # Add formatted row to the markdown table with a newline at the end
    markdown_table += f"| {table} | {bff_term if bff_term else '-'} | {csv_rows_formatted} | {bff_rows_formatted} | {completeness} |\\n"

# Display the table based on the mode
if mode == 'display':
    display(Markdown(markdown_table))
else:
    print(markdown_table)
"""

# Write the script content to a Python file
with open('create_table.py', 'w') as file:
    file.write(script_content)

# %% [markdown]
# Now execute the script:

# %%
# %run create_table.py /content/json_stats.txt /content/csv_stats.txt display
# Out:
# | OMOP-CDM Table          | BFF Term                     | # Rows in CSV | # Objects in BFF | Completeness (%) |
# |-------------------------|------------------------------|---------------|------------------|------------------|
# | CONCEPT | - | 445 | - | - |
# | CONDITION_OCCURRENCE | diseases | 65,332 | 65,332 | 100 |
# | DRUG_EXPOSURE | treatments | 67,707 | 67,707 | 100 |
# | MEASUREMENT | measures | 44,053 | 44,053 | 100 |
# | OBSERVATION | phenotypicFeatures | 1,477 | 1,477 | 100 |
# | PERSON | id | 2,694 | 2,694 | 100 |
# | PROCEDURE_OCCURRENCE | interventionsOrProcedures | 37,409 | 37,409 | 100 |
# | SPECIMEN | - | 0 | 0 | - |
# | VISIT_OCCURRENCE | - | 1,037 | - | - |

# %% [markdown]
# Nice! Now let's do the same with a file extracted with `--stream` option.
#
# First we run `Convert-Pheno` in **stream** mode:

# %%
# !bin/convert-pheno -iomop t/omop2bff/in/omop_cdm_eunomia.sql -obff omop_individuals_completeness_stream.json --out-dir /content --verbose -O -max-lines-sql 99999 --stream
# Out:
# ****************************************
# *  Phenotypic Data Model Convert Tool  *
# *          - CONVERT-PHENO -           *
# *            Version: 0.31_1             *
# *   (C) 2022-2026 Manuel Rueda, CNAG   *
# *       The Artistic License 2.0       *
# ****************************************
#
# ==== METHOD: <omop2bff> ====
# Processing: <t/omop2bff/in/omop_cdm_eunomia.sql>
# > Param: --max-lines-sql = 99999
# > Mode : --stream
#
# Reading the SQL dump...
#
# Loading <CONCEPT> in memory...
# ==============
# Rows read(total): 445
#
# Loading <PERSON> in memory...
# ==============
# Rows read(total): 2694
#
# Loading <VISIT_OCCURRENCE> in memory...
# ==============
# Rows read(total): 1037
#
# ==========================
# Rows read (sqldump-total): 4176
# ==========================
#
# ***RAM Usage***(read_sqldump):   0.0051 GB
#
# > Parameter --max-lines-sql set to: 99999
#
# ***RAM Usage***(convert_table_aoh_to_hoh(CONCEPT)):   0.0004 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(PERSON)):   0.0037 GB
#
# ***RAM Usage***(convert_table_aoh_to_hoh(VISIT_OCCURRENCE)):   0.0014 GB
#
# Processing table <CONDITION_OCCURRENCE> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# Rows processed: 40000
# Rows processed: 50000
# Rows processed: 60000
# ==============
# Rows processed(total): 65332
#
# Processing table <PROCEDURE_OCCURRENCE> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# ==============
# Rows processed(total): 37409
#
# Processing table <MEASUREMENT> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# Rows processed: 40000
# ==============
# Rows processed(total): 44053
#
# Processing table <OBSERVATION> line-by-line...
# ==============
# Rows processed(total): 1477
#
# Processing table <DRUG_EXPOSURE> line-by-line...
# Rows processed: 10000
# Rows processed: 20000
# Rows processed: 30000
# Rows processed: 40000
# Rows processed: 50000
# Rows processed: 60000
# ==============
# Rows processed(total): 67707
#
# Processing table <SPECIMEN> line-by-line...
# ==============
# Rows processed(total): 0
#
# All done!

# %% [markdown]
# Let's run the script to get the stats:

# %%
# !head -2 /content/omop_individuals_completeness_stream.json | cut -c1-100
# Out:
# {"diseases":[{"_info":{"CONDITION_OCCURRENCE":{"OMOP_columns":{"condition_concept_id":4112343,"condi
# {"diseases":[{"_info":{"CONDITION_OCCURRENCE":{"OMOP_columns":{"condition_concept_id":192671,"condit

# %% [markdown]
# We need to create a new script to parse this new data:

# %%
# @title See code
# %%bash
# Define the script
cat << 'EOF' > process_json_stream.py
import sys
import json

if len(sys.argv) != 2:
    print("Usage: python script.py <input_file>")
    sys.exit(1)

input_file = sys.argv[1]

# Initialize counts
counts = {
    "diseases": 0,
    "exposures": 0,
    "interventionsOrProcedures": 0,
    "measures": 0,
    "phenotypicFeatures": 0,
    "treatments": 0
}

unique_ids = set()

# Process each JSON object line-by-line
with open(input_file, 'r') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        try:
            data = json.loads(line)
        except json.JSONDecodeError:
            print(f"Skipping invalid JSON line: {line}")
            continue  # Skip lines that are not valid JSON

        for term in counts.keys():
            if term in data and isinstance(data[term], list):
                counts[term] += len(data[term])

        # Handle unique ids
        if "id" in data and data["id"] is not None:
            unique_ids.add(data["id"])

# Output results with tab-separated values
for term, count in counts.items():
    print(f"{term}\t{count}")

# Output unique id count
print(f"id\t{len(unique_ids)}")
EOF

# %%
# !python3 ./process_json_stream.py /content/omop_individuals_completeness_stream.json > /content/json_stats_stream.txt
# !cat /content/json_stats_stream.txt
# Out:
# diseases	65332
# exposures	0
# interventionsOrProcedures	37409
# measures	44053
# phenotypicFeatures	1477
# treatments	67707
# id	2694

# %% [markdown]
# Now we build the completeness table again:

# %%
# %run create_table.py /content/json_stats_stream.txt /content/csv_stats.txt display
# Out:
# | OMOP-CDM Table          | BFF Term                     | # Rows in CSV | # Objects in BFF | Completeness (%) |
# |-------------------------|------------------------------|---------------|------------------|------------------|
# | CONCEPT | - | 445 | - | - |
# | CONDITION_OCCURRENCE | diseases | 65,332 | 65,332 | 100 |
# | DRUG_EXPOSURE | treatments | 67,707 | 67,707 | 100 |
# | MEASUREMENT | measures | 44,053 | 44,053 | 100 |
# | OBSERVATION | phenotypicFeatures | 1,477 | 1,477 | 100 |
# | PERSON | id | 2,694 | 2,694 | 100 |
# | PROCEDURE_OCCURRENCE | interventionsOrProcedures | 37,409 | 37,409 | 100 |
# | SPECIMEN | - | 0 | 0 | - |
# | VISIT_OCCURRENCE | - | 1,037 | - | - |

# %% [markdown]
# # Optional

# %% [markdown]
# ## Downloading the Athena-OHDSI database

# %% [markdown]
# If your OMOP CDM data is not self-contained, you may need an external database to fetch the `concept_id`. To facilitate this, we will download the provided Athena-OHDSI database.

# %% [markdown]
# Unfortunately, Google does not make it easy to use `wget, curl, etc.` to perform the download so we will install Python's library `gdown`:

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# And then download the actual file to /content/ohdsi.db

# %%
# @title Show code
import gdown

url = 'https://drive.google.com/uc?export=download&id=1zQ26Q1qsqTBPDGrtZbhDP-85NhaOrfBP'
output = '/content/ohdsi.db'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1-Ls1nmgxp-iW-8LkRIuNNdNytXa8kgNw
# From (redirected): https://drive.google.com/uc?export=download&id=1-Ls1nmgxp-iW-8LkRIuNNdNytXa8kgNw&confirm=t&uuid=b68b1a34-8196-496e-9187-833db83f0aba
# To: /content/ohdsi.db
# 100%|██████████| 2.30G/2.30G [00:31<00:00, 73.4MB/s]
# '/content/ohdsi.db'

# %% [markdown]
# ## Uploading files

# %% [markdown]
# It's possible to run jobs using your own files. A few notes:
#
# * The files will be stored in **your instance** of this document. We (developers) don't have access to them.
#
# * Uploaded files will get **deleted** when this runtime is recycled.
#
# * `Convert-Pheno` does not send remote information to our servers and does not store user's information.
#
# * The security is dictated by your Google account / drive.
#
# The files can be uploaded by clicking in the upload button on the left tab of this screen. Files will be uploaded to `/content`.
#
# Once the file is uploaded, you can execute `convert-pheno` command-line as we did above.

# %% [markdown]
# Great! I hope this quick tour was useful.
#
# Now it's time to try it out yourself!
#
# Bye!!
#
# Manu
